# %%
import datapreprocessing as dp

# %%
import data

# %%
data.tag2label
# Out:
# {'B-1B': 1,
#  'B-1JC': 3,
#  'B-1JX': 5,
#  'B-1M': 7,
#  'B-1O': 9,
#  'B-1QT': 11,
#  'B-1S': 13,
#  'B-1T': 15,
#  'B-1W': 17,
#  'B-1X': 19,
#  'B-1YC': 21,
#  'B-1YW': 23,
#  'B-1ZL': 25,
#  'B-1ZS': 27,
#  'B-2B': 29,
#  'B-2JC': 31,
#  'B-2JX': 33,
#  'B-2M': 35,
#  'B-2O': 37,
#  'B-2QT': 39,
#  'B-2S': 41,
#  'B-2T': 43,
#  'B-2W': 45,
#  'B-2X': 47,
#  'B-2YC': 49,
#  'B-2YW': 51,
#  'B-2ZL': 53,
#  'B-2ZS': 55,
#  'B-3B': 57,
#  'B-3JC': 59,
#  'B-3JX': 61,
#  'B-3M': 63,
#  'B-3O': 65,
#  'B-3QT': 67,
#  'B-3S': 69,
#  'B-3T': 71,
#  'B-3W': 73,
#  'B-3X': 75,
#  'B-3YC': 77,
#  'B-3YW': 79,
#  'B-3ZL': 81,
#  'B-3ZS': 83,
#  'B-4B': 85,
#  'B-4JC': 87,
#  'B-4JX': 89,
#  'B-4M': 91,
#  'B-4O': 93,
#  'B-4QT': 95,
#  'B-4S': 97,
#  'B-4T': 99,
#  'B-4W': 101,
#  'B-4X': 103,
#  'B-4YC': 105,
#  'B-4YW': 107,
#  'B-4ZL': 109,
#  'B-4ZS': 111,
#  'B-5B': 113,
#  'B-5JC': 115,
#  'B-5JX': 117,
#  'B-5M': 119,
#  'B-5O': 121,
#  'B-5QT': 123,
#  'B-5S': 125,
#  'B-5T': 127,
# ...

# %%
dp.buildCorpus('D:\\Desktop\\产品\\辅诊\\已标\\ru1_tb_cis_mzdzbl_0.csv','D:\\Desktop\\产品\\辅诊\\已标\\aa.txt')
# Out:
# {'1b': ['食物、药物过敏史', '食物、药物过敏史'],
#  '1zs': ['口渴',
#   '多尿',
#   '多食',
#   '胸痛',
#   '气急',
#   '胸痛',
#   '咯血',
#   '胸痛',
#   '发热',
#   '头痛',
#   '头晕',
#   '耳鸣',
#   '胸闷',
#   '心悸',
#   '明显不适',
#   '头痛',
#   '黑蒙',
#   '恶心',
#   '呕吐',
#   '胸痛',
#   '心悸',
#   '行走不稳',
#   '头晕',
#   '胸闷',
#   '胸闷',
#   '心悸',
#   '明显不适',
#   '发热',
#   '吐泻',
#   '好转'],
#  '3zs': ['加重'],
#  '7zs': ['劳累史'],
#  'b': ['糖尿病史', '慢性支气管炎病史', '哮喘病史', '关节痛病史', '糖尿病病史', '胃炎胃溃疡病史', '高血压'],
#  'qt': ['体检', '配药'],
#  'w': ['颈项', '肩', '背部', '胃部'],
#  'yc': ['面色黧黑'],
#  'yw': ['感冒药物', '克感敏'],
#  'zl': ['服药', '配药', '服药'],
#  'zs': ['心悸',
#   '胸闷',
#   '板滞',
#   '酸痛',
#   '头晕',
#   '不适',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '咳嗽',
#   '腰膝疼痛',
#   '痛如针刺',
#   '胸闷',
#   '头晕',
#   '头胀',
#   '咽痛',
#   '鼻塞',
#   '咳嗽',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰',
#   '发热',
#   '胃痛',
#   '不适',
#   '发胀',
#   '嗳气',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '痰少',
#   '发热',
#   '干咳',
#   '发热',
#   '吐泻',
#   '咽痛',
#   '鼻塞',
#   '流涕',
# ...

# %%
dp.read_corpus('D:\\Desktop\\产品\\辅诊\\已标\\aa.txt')
# Out:
# [(['有',
#    '糖',
#    '尿',
#    '病',
#    '史',
#    '多',
#    '年',
#    '，',
#    '目',
#    '前',
#    '无',
#    '口',
#    '渴',
#    '，',
#    '无',
#    '多',
#    '尿',
#    '，',
#    '无',
#    '多',
#    '食',
#    '等',
#    '症',
#    '状',
#    '。',
#    '今',
#    '药',
#    '服',
#    '完',
#    '配',
#    '药',
#    '。'],
#   ['o',
#    'B-B',
#    'I-B',
#    'I-B',
#    'I-B',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'B-1ZS',
#    'I-1ZS',
#    'o',
#    'o',
#    'B-1ZS',
#    'I-1ZS',
#    'o',
#    'o',
#    'B-1ZS',
#    'I-1ZS',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o',
#    'o']),
#  (['患',
#    '者',
#    '三',
#    '周',
#    '无',
#    '明',
#    '显',
#    '诱',
#    '因',
#    '下',
#    '出',
#    '现',
#    '心',
#    '悸',
#    '、',
#    '胸',
#    '闷',
#    '，',
#    '无',
#    '胸',
#    '痛',
#    '、',
#    '气',
#    '急',
#    '等',
#    '不',
#    '适',
#    '，',
#    '面',
#    '色',
#    '黧',
#    '黑',
# ...

# %%
word2id = dp.buildVocab('word2id.pkl','D:\\Desktop\\产品\\辅诊\\已标\\merged.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-0cd554f5c5ad> in <module>()
# ----> 1 word2id = dp.buildVocab('word2id.pkl','D:\\Desktop\\产品\\辅诊\\已标\\merged.csv')
#
# D:\github\E-Tagging\code\datapreprocessing.py in buildVocab(vocab_path, corpus_path, min_count)
#     250         :return:
#     251 	"""
# --> 252         data = readCorpus(corpus_path)
#     253         word2id = {}
#     254         for sent_, tag_ in data:
#
# D:\github\E-Tagging\code\datapreprocessing.py in readCorpus(corpus_path)
#     232         for line in lines:
#     233                 if line != '\n':
# --> 234                         [char, label] = line.strip().split()
#     235                         sent_.append(char)
#     236                         tag_.append(label)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
sent = ['有', '胃', '炎', '胃', '溃', '疡', '病', '史', '，', '治', '疗', '中', '。']
dp.sentence2Id(sent,word2id)
# Out:
# [1, 49, 100, 49, 143, 144, 4, 5, 8, 145, 146, 147, 18]

# %%
dp.mergeCorpus('D:\\Desktop\\产品\\辅诊\\已标')
# Out:
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_0.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_1.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_10.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_11.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_12.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_13.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_14.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_15.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_16.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_17.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_18.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_19.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_2.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_20.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_21.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_22.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_23.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_24.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_25.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_3.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_4.csv
# ...

# %%
# os.listdir('D:\\Desktop\\产品\\辅诊\\已标')
count = 0
corpus_dir = 'D:\\Desktop\\产品\\辅诊\\已标'
for s in os.listdir(corpus_dir):
    if count > 1:
        break
    if s.endswith('.csv'):
        print(os.path.join(corpus_dir,s))
        with open(os.path.join(corpus_dir,s),'r',encoding='utf8') as f:
            l = f.readlines()
        with open(os.path.join(corpus_dir,'mm'),'a',encoding='utf8') as f:
            f.writelines(l)
        count += 1
# Out:
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_0.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_1.csv

# %%
zs=7

# %%
if dfdf:
    print('jjj')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6ab37ada6755> in <module>()
# ----> 1 if dfdf:
#       2     print('jjj')
#
# NameError: name 'dfdf' is not defined

# %%
vars()
# Out:
# {'In': ['', "if dfdf:\n    print('jjj')", 'vars()', 'zs=7', 'vars()'],
#  'Out': {2: {...}},
#  '_': {...},
#  '_2': {...},
#  '__': '',
#  '___': '',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['D:\\github\\E-Tagging\\code'],
#  '_i': 'zs=7',
#  '_i1': "if dfdf:\n    print('jjj')",
#  '_i2': 'vars()',
#  '_i3': 'zs=7',
#  '_i4': 'vars()',
#  '_ih': ['', "if dfdf:\n    print('jjj')", 'vars()', 'zs=7', 'vars()'],
#  '_ii': 'vars()',
#  '_iii': "if dfdf:\n    print('jjj')",
#  '_oh': {2: {...}},
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x24ae2e344a8>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000024AE2DDAB38>>,
# ...
