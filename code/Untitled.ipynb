# %%
import sys
sys.path.append('/home/ian/code/github')

# %%
from utils1.pickle_wrapper import pickle_wrapper as pkw

# %%
df = pkw.loadfromfile('/home/ian/code/data/e-tagging/merged180619.pkl')

# %%
df.shape
# Out:
# (8437, 16)

# %% [markdown]
# * age
# * HZXB
# 患者性别
# * XBS
# 现病史
# * JWS
# 既往史
# * ZS
# 主诉
# * XYZDMC
# 西医诊断名称

# %%
df.head(2)
# Out:
#                               JZLSH  \
# 0  00bc9b96614a40c68d6791f7a253a1ff
# 1  00e1383c07224c9ead89b7fcaf8ab04e
#
#                                YBMLBM#XMMC#YZLX#YPYF       YLJGDM  \
# 0  Z00757000020060#活血止痛胶囊#1#口服;XN0000030059621#孟鲁...  22985100300
# 1                       X00397300010010#格列吡嗪控释片#1#口服  22985100300
#
#   JCBW#JCFF#YXBX#YXZD   ZS                                                XBS  \
# 0                 NaN  NaN         时有咳嗽、咳痰,无胸痛、咯血等，慢性支气管炎病史。哮喘病史，关节痛病史，外出提前配药
# 1                 NaN  NaN  患者有长期糖尿病病史，平素按时服药，病情稳定，无头痛、头晕、无耳鸣症状，自诉血压、血糖控制可...
#
#        JWS   XYZDBM  XYZDMC ZDSM ZLCLJY HZXB JZKSMC YBJZKSBM   age BGDLB#BBMC
# 0     慢支病史  J42.x00  慢性支气管炎  NaN    NaN    m  全科医疗科       02  64.0        NaN
# 1  有糖尿病 多年  E14.900     糖尿病  NaN    NaN    0  全科医疗科       02   0.0        NaN

# %%
df['XYZDMC'].unique()
# Out:
# array(['慢性支气管炎', '糖尿病', '腰痛', ..., '眼和视力检查', '牙根滞留', '试管内受精'],
#       dtype=object)

# %%
df['ZS'].unique()
# Out:
# array([nan, '燥痹复诊', '关节肿痛10月余', ..., '慢性结肠炎复诊', '腰痛伴行走不利1天。',
#        '左中指甲旁红肿疼痛1年。'], dtype=object)

# %%
df['JWS'].unique()
# Out:
# array(['慢支病史', '有糖尿病 多年', nan, '冠心病等', '无', '冠心病高血压脑梗死等', '周围神经病糖尿病高血压等',
#        '/', '有神经炎史，夜眠不佳。', '无药敏史', '睡眠障碍等', '有高血压病史', '脑梗', '胃炎等',
#        '有乳腺增生史', '肾功能不全病史', '腰痛病史数年', '有冠心病病史', '有高血压及糖尿病及冠心病病史',
#        '前列腺增生症史', '既往有糖尿病史。', '有胆囊炎病史', '否认系统性疾病。', '磺胺过敏病史。',
#        '骨质疏松 糖尿病 脑梗死', '有冠心病病史，无其他系统疾病病史', '便秘史', '脑梗死 高血压', '病毒感染',
#        '有胃食管反流病史', '尿道综合症', '冠心病 高血压', '冠状动脉缺血', '痛风', '慢支', '有关节病便秘',
#        '高血压', '脑梗死等', '夜眠不佳。', '无。', '有高血压及冠心病病史', '肠功能紊乱，痔', '室性早搏',
#        '慢性胃炎 高血压', '骨质疏松 冠心病', '冠心病', '脑梗死', '糖尿病史', '糖尿病', '既往有关节病史。',
#        '失眠症', '有高血压史', '脑动脉供血不足 骨关节炎', '右膝关节痛 便秘', '高血压等', '睡眠障碍等。',
#        '既往有慢支史。', '糖尿病等', '便秘病史', '关节炎史', '有糖尿病史。', '牙周病失眠', '既往有冠心病史。',
#        '牙龈炎', '高脂血症高血压等', '脑供血不足等。', '无其他相关疾病病史。 ', '有眠障碍   史',
#        '慢性结肠炎 肠道菌群失常 高血脂 脑动脉供血不足', '既往有眩晕史。', '有关节炎史。', '脑卒中病史。',
#        '既往有膝关节退行性病变', '脑梗塞', '高血压 糖尿病', '高血压史', '既往有肺癌根治术史。', '骨质疏松',
#        '胃炎失眠', '腰突症', '脑梗死 ', '慢支，冠心病', '有高脂血症病史', '有高血压、糖尿病病史，无其他系统疾病病史',
# ...

# %%
df['JCBW#JCFF#YXBX#YXZD'].unique()
# Out:
# array([nan,
#        '上肢#双手正位#双手诸关节在位，部分远位指间关节间隙狭窄，关节面硬化、略毛糙，双手骨质略疏松，伴部分指骨关节缘骨质增生，左侧第2指骨部分缺如。指间关节周围软组织略肿胀。#双手退行性变。\n左侧第2指骨部分缺如。请结合临床。',
#        '脊柱#磁共振扫描(腰椎)#腰椎序列不稳,腰椎侧弯，腰1椎体轻度后移，生理性曲度存在，诸腰椎骨质增生。L1/2、L2/3椎间盘膨出，L3/4椎间盘左后突出，相应硬膜囊左侧神经根受压，L4/5椎间盘膨出，相应硬膜囊受压，L4/5两侧隐窝狭窄，L2/3、L3/4、L4/5平面椎管狭窄，腰椎诸椎间盘髓核信号T2WI及压脂信号减低，椎旁软组织无异常信号影。#1.腰3/4左后突出、左侧隐窝狭窄，腰1/2、腰2/3、腰4/5椎间盘膨出，腰\n  2/3至腰4/5平面椎管狭窄。\n2.腰椎诸椎间盘髓核变性。\n3.腰椎侧弯、退变，腰1椎体I度后滑脱。;腰椎#平扫(腰椎)#腰椎序列不稳，生理曲度存在，腰3/4、腰4/5椎间盘向四周膨出同时向后突出稍显，相应硬膜囊受压，相应平面椎管狭窄。腰2/3椎间盘真空征，腰2/3椎间盘向右后方突出，相应平面椎管略狭窄，相应椎管内气体密度影。诸椎体及椎间小关节骨质增生，腰5双侧椎弓连续性中断。#1、腰椎退行性变，腰5双侧椎弓崩裂。\n2、腰3/4、腰4/5椎间盘膨出伴突出、相应平面椎管狭窄。\n3、腰2/3椎间盘变性、突出，相应平面椎管轻度狭窄。\n请结合临床，必要时进一步MRI检查。',
#        '上肢,下肢,胸部#双手正位,双足正位,胸部正侧位#所示胸廓对称。纵隔未见增宽。两肺野纹理略增多，双膈面光整，两肋膈角锐利。主动脉不宽。心影饱满。\n双手诸指骨端及腕骨骨质略疏松，双腕关节及近位指间关节间隙未见狭窄，近位指间关节周围及腕掌部软组织略肿胀。\n双足诸关节在位，诸骨端骨质略疏松，跖趾关节及跗骨关节间隙未见狭窄。#两肺纹理稍增多。\n双手、双足轻度骨质疏松。请结合临床。',
# ...
