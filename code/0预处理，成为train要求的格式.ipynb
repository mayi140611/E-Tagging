# %%
步骤：
* 人工打标签前的工作：去除每行文本中的空格
* 人工打标签前的工作：把大文件转化为20行的小文件
* 要标注的小文件merge成大的csv
* 构建corpus
* 构建word2id

# %%
import datapreprocessing as dp
import os

# %%
corpus_dir = 'D:\\Desktop\\产品\\辅诊\\已标'
dp.mergeCSV(corpus_dir)
# Out:
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_31.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_32.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_33.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_34.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_35.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_36.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_37.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_38.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_39.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_40.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_41.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_42.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_43.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_44.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_45.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_46.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_47.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_48.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_49.csv
# D:\Desktop\产品\辅诊\已标\markedru1_tb_cis_mzdzbl_50.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_0.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_1.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_10.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_11.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_12.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_13.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_14.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_15.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_16.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_17.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_18.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_19.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_2.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_20.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_21.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_22.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_23.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_24.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_25.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_3.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_4.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_5.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_6.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_7.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_8.csv
# D:\Desktop\产品\辅诊\已标\ru1_tb_cis_mzdzbl_9.csv

# %%
dp.buildCorpus(os.path.join(corpus_dir,'merged.csv'),os.path.join(corpus_dir,'corpus'))
# Out:
# {'1b': ['皮肤病史',
#   '排除/AS',
#   '食物、药物过敏史',
#   '食物、药物过敏史',
#   '食物、药物过敏史',
#   '药物过敏史',
#   '药敏史',
#   '虹睫炎',
#   '虹睫炎',
#   '糖尿病',
#   '高血压',
#   '糖尿病病史'],
#  '1jc': ['狭窄',
#   '栓塞',
#   '狭窄',
#   '尿蛋白',
#   '错位性骨折征象',
#   '阳性检查结果',
#   '狭窄',
#   '异常',
#   '异常',
#   '异常',
#   '眼科检查眼底血管(-)',
#   '异常',
#   '扩张',
#   '狭窄'],
#  '1s': ['外伤史',
#   '外伤',
#   '外伤',
#   '外伤',
#   '肢体浮肿',
#   '骨折',
#   '气急',
#   '恶心呕吐',
#   '外伤史',
#   '外伤',
#   '外伤'],
#  '1yc': ['早搏'],
#  '1yw': ['骨折', '英太青', '秋水仙碱', '英太青', '美卓乐', '来氟米特', '强的松', '美卓乐', 'MTX'],
#  '1zl': ['颈椎间盘摘除内固定术', '自服药物', '停药', '服药', '激素', '药物治疗', '放环'],
#  '1zs': ['关节疼痛肿胀',
#   '关节疼痛肿胀',
#   '多关节肿痛',
#   '关节肿痛',
#   '晨僵',
#   '发热',
#   '关节肿痛',
#   '晨僵',
#   '发热',
#   '发热',
#   '关节（-）',
#   '皮疹',
#   '口眼干',
#   '间歇性跛行',
#   '发热',
#   '呕吐黑便',
#   '关节疼痛肿胀',
#   '关节疼痛肿胀',
#   '恶心',
#   '呕吐',
#   '泛酸',
#   '嗳气',
#   '发热',
#   '关节痛',
#   '关节疼痛',
#   '腰背',
#   '恶心',
#   '呕吐',
#   '关节疼痛',
#   '关节疼痛肿胀',
#   '关节肿痛',
#   '关节病情',
#   '咽痛',
#   '关节疼痛肿胀',
#   '关节疼痛肿胀',
#   '关节疼痛肿胀',
#   '不适',
#   '咳嗽',
#   '咳痰',
#   '鼻塞',
#   '流涕',
#   '乏力',
#   '发烧',
#   '光过敏',
#   '脱发',
#   '口干',
#   '眼干',
#   '虹睫炎',
#   '腹泻',
#   '口腔溃疡生殖器溃疡',
#   '牙齿脱落',
#   '下肢放射痛',
#   '发热',
#   '腹痛',
#   '发热',
#   '痰少',
#   '上肢麻',
#   '头晕',
#   '咳嗽',
#   '鼻塞',
#   '流涕',
#   '关节疼痛肿胀',
#   '关节肿痛',
#   '体重减轻',
#   '发热',
#   '发热',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '禽类、确诊或疑似H7N9患者接触史',
#   '疫源地接触史',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '禽类、确诊或疑似H7N9患者接触史',
#   '疫源地接触史',
#   '头痛',
#   '头晕',
#   '肢体活动障碍',
#   '发热',
#   '不适',
#   '不适',
#   '不适',
#   '发热',
#   '发热',
#   '发热',
#   '发热',
#   '发热',
#   '发热',
#   '咳痰',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '禽类、确诊或疑似H7N9患者接触史',
#   '疫源地接触史',
#   '不适',
#   '腹泻',
#   '不适',
#   '发热',
#   '腹泻',
#   '发热',
#   '不适',
#   '关节肿胀疼痛',
#   '泛酸',
#   '嗳气',
#   '腹泻',
#   '胸闷',
#   '心慌',
#   '关节肿痛',
#   '痰',
#   '胸闷',
#   '气粗',
#   '心慌',
#   '胸痛',
#   '发热',
#   '盗汗',
#   '体重减轻',
#   '发热',
#   '咽痛',
#   '咳嗽',
#   '尿频急',
#   '腹泻',
#   '不适',
#   '躯体不适',
#   '不适',
#   '吵闹基本消失',
#   '不适',
#   '吵闹',
#   '不适',
#   '烦躁',
#   '不适',
#   '心烦表现',
#   '不适',
#   '躯体不良反应',
#   '药物不良反应',
#   '不适',
#   '躯体不良反应',
#   '药物不良反应',
#   '不适',
#   '躯体不',
#   '不适',
#   '躯体不适',
#   '不良反应',
#   '躯体不适',
#   '躯体不适',
#   '躯体不适',
#   '躯体不适',
#   '冲动行为',
#   '毁物行为',
#   '打人伤人行为',
#   '外出乱跑现象',
#   '自伤',
#   '自杀行为',
#   '躯体不适',
#   '躯体不适',
#   '不适',
#   '不适',
#   '吵闹',
#   '躯体不适',
#   '躯体不适',
#   '多思',
#   '多虑',
#   '不良药物反应',
#   '躯体不适',
#   '冲动行为',
#   '毁物行为',
#   '打人',
#   '伤人',
#   '外出乱跑现象',
#   '自伤',
#   '自杀行为',
#   '躯体不适',
#   '躯体不适',
#   '躯体不适',
#   '不适',
#   '躯体不适',
#   '躯体不适',
#   '躯体不适',
#   '躯体不适',
#   '药物不良反应',
#   '胸闷',
#   '躯体不适',
#   '不良',
#   '反应',
#   '躯体不适',
#   '躯体不适',
#   '发热',
#   '外周关节肿痛',
#   '双足跟关节疼痛',
#   '皮疹',
#   '口腔溃疡',
#   '慢性腹泻',
#   '肿痛',
#   '饥饿感',
#   '恶心呕吐',
#   '皮疹',
#   '口腔溃疡',
#   '雷诺氏征',
#   '家族史',
#   '呕吐',
#   '黑便',
#   '腹泻',
#   '关节肿痛',
#   '肿痛',
#   '晨僵',
#   '关节',
#   '肿痛',
#   '晨僵',
#   '口渴',
#   '多尿',
#   '多食',
#   '胸痛',
#   '气急',
#   '胸痛',
#   '咯血',
#   '胸痛',
#   '发热',
#   '头痛',
#   '头晕',
#   '耳鸣',
#   '胸闷',
#   '心悸',
#   '明显不适',
#   '头痛',
#   '黑蒙',
#   '恶心',
#   '呕吐',
#   '胸痛',
#   '心悸',
#   '行走不稳',
#   '头晕',
#   '胸闷',
#   '胸闷',
#   '心悸',
#   '明显不适',
#   '发热',
#   '吐泻',
#   '好转',
#   '头痛',
#   '头晕',
#   '发热',
#   '发热',
#   '活动受限',
#   '乳头溢液',
#   '恶心呕吐',
#   '胸闷',
#   '胸痛气急',
#   '咳嗽',
#   '流涕',
#   '咳嗽',
#   '腹泻',
#   '呕吐',
#   '腹痛',
#   '恶心',
#   '呕吐',
#   '腹痛',
#   '腹泻',
#   '发热',
#   '肢体乏力',
#   '恶心呕吐',
#   '打嗝',
#   '恶心呕吐',
#   '腹泻',
#   '多饮',
#   '多食',
#   '多尿',
#   '腹胀',
#   '腹痛',
#   '排尿困难',
#   '腹胀',
#   '恶心',
#   '呕吐',
#   '泛酸嗳气',
#   '发热',
#   '出血',
#   '咳嗽',
#   '发热',
#   '头晕',
#   '胸闷',
#   '咳嗽',
#   '发热',
#   '胸闷',
#   '胸痛',
#   '呼吸困难',
#   '胸闷',
#   '胸痛',
#   '胸闷',
#   '胸痛',
#   '发热',
#   '胸痛',
#   '明显发热',
#   '口眼歪斜',
#   '头晕',
#   '眩晕',
#   '气促',
#   '胸闷',
#   '胸痛',
#   '胸闷气促',
#   '发热',
#   '头晕',
#   '头痛',
#   '黑曚',
#   '意识障碍',
#   '发热',
#   '发热',
#   '发热',
#   '发热',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷心慌',
#   '禽类、确诊或疑似H7N9患者接触史',
#   '疫源地接触史',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '禽类、确诊或疑似H7N9患者接触史',
#   '疫源地接触史',
#   '不适',
#   '腹泻',
#   '发热',
#   '泛酸',
#   '胸痛',
#   '腰痛',
#   '黑便',
#   '腹痛',
#   '呕吐',
#   '胸闷',
#   '心慌',
#   '头晕',
#   '冷汗',
#   '反酸',
#   '头晕',
#   '心慌',
#   '晕厥',
#   '心前区痛',
#   '端坐呼吸',
#   '夜间阵法性呼吸困难',
#   '双下肢水肿',
#   '气促',
#   '胸闷',
#   '胸痛',
#   '发热',
#   '头晕',
#   '左下肢乏力',
#   '语言障碍',
#   '咳嗽',
#   '咳痰',
#   '尿频',
#   '尿痛',
#   '腹痛',
#   '腹泻',
#   '咳嗽',
#   '阵发性气促',
#   '不适',
#   '药物过敏史',
#   '发热',
#   '咳嗽',
#   '咽痛',
#   '咳嗽',
#   '呕吐',
#   '腹泻',
#   '咳嗽',
#   '气促',
#   '发热',
#   '痰咳不畅',
#   '胸闷',
#   '胸痛',
#   '胸痛',
#   '不适',
#   '发热',
#   '咳嗽',
#   '咳痰',
#   '痛',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '禽类、确诊或疑似H7N9患者接触史',
#   '疫源地接触史',
#   '发热',
#   '发热',
#   '胸闷',
#   '胸痛',
#   '头晕',
#   '尿频',
#   '尿急',
#   '尿痛',
#   '发热',
#   '腹痛',
#   '呕吐',
#   '抽搐',
#   '腹泻',
#   '咽痛',
#   '咳嗽',
#   '咳痰',
#   '流涕',
#   '黑便',
#   '脓血便',
#   '头晕',
#   '头晕',
#   '肢体肌力减退',
#   '不适',
#   '不适',
#   '晨僵',
#   '吞咽困难',
#   '小关节肿痛',
#   '雷诺光敏',
#   '口腔溃疡',
#   '口干',
#   '眼干',
#   '龋齿',
#   '皮疹',
#   '眼炎',
#   '腹痛',
#   '腹泻',
#   '尿频',
#   '尿急',
#   '尿痛',
#   '口干',
#   '眼干',
#   '关节疼痛',
#   '晨僵',
#   '关节肿痛',
#   '口干',
#   '眼干',
#   '口腔溃疡',
#   '发热',
#   '关节肿痛',
#   '晨僵',
#   '胸痛',
#   '发热',
#   '流涕',
#   '胸痛',
#   '疼痛',
#   '呕吐黑便',
#   '呕吐黑便',
#   '发热',
#   '口腔溃疡',
#   '口干',
#   '眼干',
#   '红斑',
#   '皮疹',
#   '腹痛',
#   '腹泻',
#   '发热',
#   '咳嗽',
#   '关节肿痛',
#   '晨僵',
#   '口干',
#   '眼干',
#   '口腔溃疡',
#   '发热',
#   '胸痛',
#   '关节疼痛肿胀',
#   '关节疼痛肿胀',
#   '关节肿痛',
#   '关节肿痛',
#   '关节肿胀疼痛',
#   '气喘',
#   '气急',
#   '咽喉不利',
#   '发热',
#   '胸闷',
#   '胸痛',
#   '胸闷',
#   '胸痛',
#   '明显不适',
#   '吐',
#   '腹痛',
#   '头昏',
#   '头痛',
#   '恶心呕吐',
#   '肢体麻木',
#   '胸痛',
#   '多食',
#   '多饮',
#   '多尿',
#   '泡沫尿',
#   '胸闷',
#   '不适',
#   '发热',
#   '咳嗽',
#   '咳痰',
#   '胸闷',
#   '气喘',
#   '头晕',
#   '头痛',
#   '恶心',
#   '呕吐',
#   '关节疼痛',
#   '视物旋转',
#   '发热',
#   '气促',
#   '胸闷心慌',
#   '发热',
#   '咳痰',
#   '胸痛',
#   '咳嗽',
#   '胸痛',
#   '小关节肿痛',
#   '皮疹脱屑',
#   '环形红斑',
#   '家族史',
#   '不适',
#   '发热',
#   '不适',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '咳痰',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '四肢关节疼痛',
#   '咽痛',
#   '发热',
#   '咳嗽',
#   '咳痰',
#   '关节肿痛',
#   '胸痛',
#   '咯血',
#   '气急',
#   '胸闷',
#   '心慌',
#   '气急',
#   '胸闷',
#   '心慌',
#   '乏力',
#   '发烧',
#   '尿蛋白',
#   '光过敏',
#   '脱发',
#   '口干',
#   '眼干',
#   '腹泻',
#   '口腔溃疡',
#   '生殖器溃疡',
#   '牙齿脱落',
#   '四肢肿胀',
#   '恶心',
#   '呕吐',
#   '关节肿痛',
#   '发热',
#   '恶心',
#   '呕吐',
#   '嗳气',
#   '反酸',
#   '腹泻',
#   '发烧',
#   '尿蛋白',
#   '光过敏',
#   '脱发',
#   '虹睫炎',
#   '腹泻',
#   '口腔溃疡',
#   '生殖器溃疡',
#   '牙齿脱落',
#   '雷诺光敏',
#   '尿频',
#   '尿急',
#   '尿痛',
#   '腹痛',
#   '关节肿痛',
#   '关节疼痛肿胀',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰',
#   '腰部酸痛',
#   '腹痛',
#   '发热',
#   '咳嗽',
#   '腹泻',
#   '胸闷',
#   '尿痛',
#   '发热',
#   '腹泻',
#   '肿胀',
#   '关节疼痛肿胀',
#   '关节疼痛肿胀',
#   '肿胀',
#   '皮肤干燥',
#   '眼周皮疹',
#   '疼痛',
#   '发热',
#   '发热',
#   '腹泻',
#   '恶心呕吐',
#   '发热',
#   '关节游走性疼痛',
#   '关节疼痛',
#   '头痛',
#   '头晕',
#   '耳鸣',
#   '腹胀',
#   '腹痛',
#   '便血',
#   '恶心',
#   '呕吐',
#   '食欲减退',
#   '右下后牙疼痛',
#   '腹痛',
#   '发热',
#   '水样便',
#   '恶心',
#   '呕吐',
#   '不洁饮食史',
#   '咳嗽',
#   '咳痰',
#   '头痛',
#   '胸痛',
#   '气急',
#   '口渴',
#   '头晕',
#   '恶心',
#   '呕吐',
#   '不适',
#   '乏力',
#   '阴道出血',
#   '左下肢麻木感',
#   '药物过敏史',
#   '多饮',
#   '多尿',
#   '胸闷',
#   '胸痛',
#   '胸闷',
#   '胸痛',
#   '呼吸困难',
#   '粘冻',
#   '脓血',
#   '发热',
#   '胸闷',
#   '胸痛',
#   '食物、药物过敏史',
#   '胸闷',
#   '心悸',
#   '咳嗽',
#   '咳痰',
#   '气喘',
#   '渗出',
#   '不洁饮食病史',
#   '头晕',
#   '不适',
#   '畏寒',
#   '腹痛',
#   '咳嗽',
#   '咳痰',
#   '气喘',
#   '耳鸣',
#   '黑蒙',
#   '目眩',
#   '冰冷',
#   '麻木',
#   '不适',
#   '外阴瘙痒',
#   '腰酸',
#   '发热',
#   '头痛',
#   '头晕',
#   '不良反应',
#   '视物旋转',
#   '恶心呕吐',
#   '心悸',
#   '气促',
#   '鼻塞',
#   '流涕',
#   '发热',
#   '胸闷',
#   '心悸',
#   '胸痛',
#   '气促',
#   '头晕',
#   '头痛',
#   '恶心',
#   '呕吐',
#   '四肢酸痛',
#   '发热',
#   '腹泻',
#   '尿痛',
#   '关节酸痛',
#   '头痛',
#   '头晕',
#   '耳鸣',
#   '嗳气',
#   '咳嗽',
#   '咳痰',
#   '胸闷',
#   '气促',
#   '怀孕',
#   '头痛',
#   '头晕',
#   '耳鸣',
#   '食物、药物过敏史',
#   '胸闷不适',
#   '胃部不适',
#   '黑蒙',
#   '目眩',
#   '冰冷',
#   '麻木',
#   '多饮',
#   '多食',
#   '多尿',
#   '胸闷',
#   '胸痛',
#   '头痛',
#   '耳鸣',
#   '食物、药物过敏史',
#   '头晕',
#   '心慌',
#   '胸闷',
#   '咳痰',
#   '发热',
#   '右下肢麻木',
#   '视物旋转',
#   '肢体活动障碍',
#   '腹泻',
#   '发热',
#   '眼痛',
#   '腹痛',
#   '发热',
#   '产后大出血',
#   '咽喉疼痛',
#   '不适',
#   '胸闷',
#   '胸痛',
#   '呼吸困难',
#   '头痛',
#   '耳鸣',
#   '食物、药物过敏史',
#   '黑蒙',
#   '目眩',
#   '冰冷',
#   '麻木',
#   '食物、药物过敏史',
#   '发热',
#   '咳嗽',
#   '流涕',
#   '吐泻',
#   '胸闷',
#   '胸痛',
#   '流涕',
#   '咳嗽',
#   '腹泻',
#   '呕吐',
#   '腹痛',
#   '口干',
#   '多饮',
#   '多尿',
#   '低血糖反应',
#   '手足麻木刺痛',
#   '视物不清',
#   '泡沫尿',
#   '阴道出血'],
#  '2b': ['糖尿病史', '糖尿病史'],
#  '3jc': ['肝损', '血糖升高', '胆囊壁稍毛糙'],
#  '3yw': ['LEF'],
#  '3zs': ['昏迷',
#   '外物旋转',
#   '加重',
#   '疼痛',
#   '腹痛',
#   '中下腹痛',
#   '劳累受寒后腰部不适',
#   '疼痛',
#   '消化道出血',
#   '难以入眠',
#   '脸部浮肿',
#   '头晕',
#   '恶心欲吐',
#   '疲劳',
#   '犯困',
#   '麻木不适',
#   '胃部不适',
#   '胃部不适',
#   '血压波动',
#   '头晕',
#   '手指僵硬',
#   '头晕',
#   '乏力',
#   '腰部不适',
#   '活动时明显',
#   '活动时明显',
#   '气急',
#   '汗出',
#   '心悸怔忡',
#   '气急',
#   '汗出',
#   '心悸怔忡',
#   '腰酸',
#   '乏力'],
#  '4b': ['脑梗', '椎体血管瘤', '，至当地医院就诊，查验指标后，考虑'],
#  '6zs': ['咳嗽',
#   '暧酸',
#   '暧气',
#   '关节疼痛',
#   '胸闷',
#   '心慌',
#   '怀疑',
#   '流口水',
#   '糊',
#   '胀',
#   '双上肢麻木',
#   '疼痛',
#   '听力下降',
#   '嗳气',
#   '咳时偶有痛引胸胁',
#   '下肢抽筋',
#   '下肢抽筋',
#   '下肢抽筋',
#   '早醒',
#   '双下肢放射痛感',
#   '右下肢麻痛',
#   '肿痛',
#   '晨僵',
#   '胸闷',
#   '心悸',
#   '发苦',
#   '恶心',
#   '呕吐',
#   '胸闷',
#   '心悸',
#   '心悸',
#   '不适',
#   '头晕',
#   '阴道分泌物',
#   '外阴瘙痒',
#   '腰酸',
#   '嗳气',
#   '阴道分泌物',
#   '腹痛',
#   '腹胀',
#   '头晕',
#   '耳鸣',
#   '头晕',
#   '心悸不适',
#   '流泪',
#   '头晕',
#   '耳鸣'],
#  '7b': ['类风关',
#   '强直性脊柱炎',
#   '胃出血',
#   '阿尔茨海默病',
#   '精神分裂症',
#   '类风关',
#   '胃窦炎病史',
#   '左侧股骨粗隆骨折后',
#   '骨关节炎病史',
#   '糖尿病',
#   '维生素缺乏',
#   '消化道出血',
#   '急性上呼吸道感染',
#   '感冒',
#   '颈椎病',
#   '类风关',
#   '扭伤病史',
#   '脑梗塞史',
#   '脑功能退化',
#   '高脂血症',
#   '前列腺增生',
#   '类风湿病史',
#   '类风湿性关节炎',
#   '类风关',
#   '慢支伴感染',
#   '反流性食管炎病史',
#   '肠功能紊乱史',
#   '骨折',
#   '中耳炎病史',
#   '脑梗塞史',
#   '老年性阴道炎病史',
#   '脑梗塞史',
#   '肾病'],
#  '7jc': ['RF偏高',
#   'HLA-B27阳性',
#   '脑萎缩',
#   '乙肝表面抗原（+）',
#   '小三阳',
#   'HBV-DNA(-)',
#   '双足跟骨质增生',
#   '胸椎段椎体骨质增生',
#   'UA偏高',
#   '退行性病变',
#   '血尿酸升高',
#   '空腹血糖升高',
#   'ESR高',
#   'RF（-）',
#   '抗CCP（—）',
#   '抽出淘米色浑浊液体',
#   'RF偏高',
#   '两肺间质性改变',
#   'CCP偏高',
#   'ANA（+）',
#   '抗SSA/Ro52抗体（+）',
#   'CRP偏高',
#   '肺结节',
#   '右肩轻度退变',
#   '失神经电位改变',
#   '尿酸偏高史'],
#  '7m': ['心脏支架'],
#  '7s': ['右股骨粗隆间骨折'],
#  '7t': ['ANA',
#   '尿微量白蛋白',
#   'RF',
#   '抗CCP',
#   'ESR',
#   'CRP',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   '胸部CT',
#   'CT',
#   '血常规',
#   'CRP',
#   '肝肾功能',
#   'CCP',
#   'RF',
#   '肌电图'],
#  '7yw': ['激素',
#   '美卓乐',
#   'MTX',
#   '氟米特',
#   'HCQ',
#   '强的松',
#   '痛风定',
#   'MTX',
#   'MTX',
#   '地塞米松',
#   '扶他林',
#   '苯溴马隆',
#   '别嘌呤醇',
#   '激素',
#   '美卓乐',
#   'MTX',
#   '氟米特',
#   'MTX',
#   'SASP',
#   '戴芬中药',
#   '安眠药',
#   '活血化瘀',
#   '安眠药',
#   '拉西酮针剂',
#   '奥氮平',
#   '阿立派唑',
#   '劳拉西泮',
#   '齐拉西酮胶囊',
#   '激素',
#   '美卓乐',
#   'MTX',
#   '氟米特',
#   'MTX',
#   '白芍',
#   'SASP',
#   '恩替卡韦',
#   '叶酸',
#   'SASP',
#   'MTX',
#   '得宝松',
#   '感冒药物',
#   '甲钴胺',
#   '痹祺胶囊',
#   '中药汤药',
#   '头孢',
#   '阿莫西林',
#   '中草药',
#   '美洛昔康',
#   '+羟基氯喹',
#   '氨基葡萄糖',
#   '激素',
#   '美卓乐',
#   '中药',
#   'MTX',
#   '来氟米特',
#   '氟米特',
#   'MTX',
#   '爱若华',
#   '激素',
#   '美卓乐',
#   '中药',
#   '双氯芬酸钠',
#   '、雷公藤多甙片',
#   '壮骨关节胶囊',
#   '美卓乐',
#   'MTX',
#   '复方风湿宁胶囊',
#   '活血止痛胶囊',
#   'MTX',
#   '羟基氯喹',
#   '莫比可',
#   '头孢克洛',
#   '克感敏',
#   '秋水仙碱片',
#   '痛风定',
#   '秋水仙碱',
#   '痛风定'],
#  '7zl': ['心脏搭桥术后',
#   '住院治疗',
#   '直肠癌术后',
#   '化疗',
#   '升血小板',
#   '保肝治疗',
#   '结肠癌术后',
#   '化疗',
#   '右手外伤术后',
#   '左上肺癌术后',
#   '关节腔抽液治疗',
#   '双膝双髋置换术后',
#   '左肩关节镜术后',
#   '左肩关节镜关节松解',
#   '冈上肌腱修补',
#   '肱二头肌长头腱固定术',
#   '左眼白内障术后',
#   '右膝关节置换术后',
#   '右膝关节置换术后',
#   '腰椎术后',
#   '右肩关节镜术后',
#   '关节囊松解',
#   '岗上肌腱修补',
#   '肱二头肌长头腱固定术',
#   '右眼白内障术后',
#   '药物关节腔注射',
#   '关节腔注射',
#   '左肩关节镜术后',
#   '左肩关节镜下关节松解',
#   '冈上肌腱修补',
#   '肱二头肌长头腱固定术',
#   '双膝关节腔抽液治疗',
#   '右膝关节腔抽液',
#   '左膝关节腔抽液',
#   '右侧股骨粗隆间骨折术后',
#   '内固定术',
#   '抗感染',
#   '左肩关节镜术后',
#   '左肩关节镜关节松解',
#   '冈上肌腱修补',
#   '肱二头肌长头腱固定术',
#   '左乳腺癌术后',
#   '剖宫产',
#   '骨水泥注射治疗史',
#   '胆囊切除',
#   '剖宫产',
#   '末次人流',
#   '左膝关节手术史'],
#  '7zs': ['疼痛',
#   '畸形肿胀',
#   '晨僵',
#   '眩晕倒地',
#   '疼痛',
#   '畸形肿胀',
#   '晨僵',
#   '关节肿痛',
#   '食用隔餐食物',
#   '食用隔餐食物',
#   '猜疑',
#   '耳闻人语',
#   '听到同学说她坏话',
#   '家里有窃听器',
#   '认为老师针对自己',
#   '幻听',
#   '一反常态',
#   '做鬼脸',
#   '傻笑',
#   '四肢关节疼痛',
#   '畸形肿胀',
#   '晨僵',
#   '结肠癌术后',
#   '泛酸',
#   '胃痛',
#   '劳累史',
#   '发热',
#   '双手麻木',
#   '右膝关节肿痛',
#   '双膝关节肿痛不适',
#   '怕冷不适',
#   '口干',
#   '腰酸腰痛',
#   '关节板滞怕冷',
#   '麻木不适',
#   '晨僵',
#   '疼痛',
#   '畸形肿胀',
#   '晨僵',
#   '肿痛不适',
#   '颜面部浮肿',
#   '肿胀',
#   '疼痛',
#   '关节肿痛'],
#  'b': ['骨关节炎',
#   '肾功能不全',
#   '糖尿病',
#   'RA',
#   'AS',
#   'AS',
#   'RA',
#   '高血压',
#   '高血压',
#   '尫痹',
#   'RA',
#   '尫痹',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '慢支病史',
#   '高血压',
#   'STILL综合症',
#   'STILL综合症',
#   'OA',
#   '0A',
#   '类风关',
#   'OA',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '痛风',
#   'RA',
#   '眩晕病史',
#   'OA',
#   '痛风病史',
#   '脑梗塞',
#   '高血压',
#   'OA',
#   'OP',
#   '骨关节炎',
#   '假性痛风',
#   'AS',
#   'RA',
#   'RA',
#   'RA',
#   '痛风',
#   'RA',
#   '痛风病史',
#   '类风湿关节炎',
#   '胃肠炎',
#   'RA',
#   '禀赋不足',
#   '后天失调',
#   '病久失养',
#   '久虚不复',
#   '慢性演变',
#   '阳痿不举',
#   '颈椎病',
#   'RA',
#   '心悸不适',
#   '脑梗塞',
#   '脑梗塞病史',
#   '糖尿病',
#   '高血压史',
#   '脑部血管瘤',
#   '脑梗塞',
#   '糖尿病',
#   '肾病',
#   '糖尿病肾病',
#   'RA',
#   '类风湿关节炎',
#   'RA',
#   '癫痫',
#   '痛风',
#   '痛风',
#   '痛风',
#   'RA',
#   '慢性胃炎',
#   '失眠',
#   'AS',
#   '高血压',
#   '冠心病',
#   '精力减退',
#   '浑身不舒服',
#   '慢性',
#   '类风湿性关节炎',
#   'RA病史',
#   'RA',
#   '自免肝',
#   '痛风',
#   'RA',
#   '反应性关节炎',
#   '感冒',
#   'RA',
#   '高血压',
#   '脑梗',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '萎缩性胃炎',
#   '糜烂',
#   'OA',
#   'RA',
#   'RA',
#   '糖尿病',
#   '糖尿病',
#   '高血压史',
#   '糖尿病',
#   '糖尿病',
#   '高血压史',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '高血压',
#   'RA',
#   'RA',
#   '类风湿关节炎',
#   '痛风',
#   '银屑病',
#   '干眼病',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '高血压',
#   'RA',
#   'RA',
#   '皮肌炎',
#   '类风湿关节炎',
#   '自身免疫性肝病',
#   '自免肝',
#   'RA',
#   'OP',
#   '慢性鼻炎',
#   '上呼吸道感染',
#   'RA',
#   '糖尿病',
#   '糖尿病',
#   '高血压史',
#   '糖尿病史',
#   '慢性支气管炎病史',
#   '哮喘病史',
#   '关节痛病史',
#   '糖尿病病史',
#   '胃炎胃溃疡病史',
#   '高血压',
#   '前列腺癌',
#   '慢性胃炎',
#   '慢性胃炎',
#   '高血压病',
#   '高血压',
#   '高血压',
#   '高脂血症',
#   '糖尿病',
#   '糖尿病',
#   '上感',
#   '上感',
#   '甲减',
#   '骨质疏松',
#   '糖尿病',
#   '骨质疏松',
#   '糖尿病',
#   '甲减',
#   '颈椎病',
#   '白内障病史',
#   '高血脂病史',
#   '高血压史',
#   '胃痛隐隐',
#   '胃部不适发胀',
#   '脑梗后遗症史',
#   '维生素E缺乏',
#   '糖尿病病史',
#   '前列腺增生病史',
#   '冠心病',
#   '心律失常',
#   '高脂血症',
#   '冠状动脉粥样硬化性心脏病',
#   '冠状动脉粥样硬化性心脏病',
#   '关节退行性病变',
#   '骨质疏松（中度）',
#   '糖尿病',
#   '脑梗塞',
#   '湿疹',
#   '脑梗塞',
#   '气管炎',
#   '高血压',
#   '脑梗',
#   '腔梗',
#   '高血压病',
#   '肺炎',
#   '肺炎',
#   '胃间质瘤',
#   '甲状腺功能减退',
#   '甲减',
#   '月经紊乱',
#   '骨质疏松',
#   '燥痹',
#   'OA',
#   'RA',
#   'AS',
#   'RA',
#   '痛风病史',
#   'RA',
#   'RA',
#   'RA',
#   '高血压',
#   'RA',
#   '冠心病',
#   'RA',
#   'RA',
#   'RA',
#   '骨质疏松',
#   'RA',
#   '呼吸道感染',
#   'RA',
#   'RA',
#   '痛风性关节炎',
#   'GOUT病史',
#   '高尿酸血症',
#   '痛风',
#   '冠状动脉粥样硬化性心脏病',
#   '糖尿病',
#   '高血压',
#   '冠心病',
#   '糖尿病',
#   '心脏病',
#   '高血压病',
#   '高血压',
#   '糖尿病',
#   '腔梗',
#   '高血压',
#   'RA',
#   'RA',
#   'RA',
#   '上感',
#   'RA',
#   'AS',
#   'AS',
#   '痛风',
#   '痛风',
#   'RA',
#   '上感',
#   'RA',
#   'RA',
#   'RA',
#   'RA病史',
#   'RA',
#   'RA',
#   '尫痹',
#   'RA',
#   'RA',
#   '类风湿关节炎',
#   'RA',
#   'RA',
#   'RA',
#   'OA',
#   'RA',
#   '萎缩性胃炎伴糜烂',
#   'RA',
#   'RA',
#   '类风湿性关节炎',
#   '高血压',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '脂肪肝',
#   '高血压',
#   '神经性皮炎',
#   'RA',
#   'RA',
#   'RA',
#   'RA',
#   '高血压史',
#   '冠心病',
#   '角膜炎',
#   '便秘史',
#   '感冒',
#   '脑供血不足史',
#   '高血压',
#   '糖尿病史',
#   '心律失常病史',
#   '前列腺增生病史',
#   '糖尿病',
#   '糖尿病',
#   '角膜炎',
#   '结膜炎史',
#   '心脏病史',
#   '房早',
#   '尿毒症',
#   '肝损害',
#   '糖尿病',
#   '冠心病病史',
#   '高血压病史',
#   '高血压史',
#   '脑血管病史',
#   '痛风',
#   '骨质疏松症',
#   '轻度脑梗',
#   '颈椎病',
#   '骨质疏松',
#   '高血压史',
#   '高血压史',
#   '前列腺增生',
#   '失眠',
#   '糖尿病史',
#   '高血压',
#   '慢性胆囊炎',
#   '心律失常',
#   '关节病',
#   '关节炎病史',
#   '结膜炎',
#   '鼻炎',
#   '上感',
#   '感冒',
#   '慢性胃炎',
#   '脑梗后遗症史',
#   '关节炎病史',
#   '糖尿病病史/',
#   '慢性胃炎',
#   '骨质疏松症',
#   '糖尿病病史',
#   '过敏性皮炎',
#   '骨质疏松',
#   '肾结石',
#   '肾囊肿',
#   '青光眼',
#   '感冒',
#   '冠心病',
#   '心律失常病史',
#   '失眠病史',
#   '慢支病史',
#   '骨质疏松',
#   '高血压病史',
#   '高血压病史',
#   '冠心病病史',
#   '高血压',
#   '便秘病史',
#   '左上后牙疼痛病史',
#   '肺结节病史',
#   '高脂血症',
#   '输尿管结石',
#   '上感',
#   '上感',
#   '糖尿病',
#   '子宫肌腺症',
#   '糖尿病',
#   '糖尿病史',
#   '骨质疏松',
#   '结膜炎',
#   '霰粒肿'],
#  'jc': ['腰椎轻度退行性变',
#   '椎间盘膨出',
#   '不完全性血栓形成',
#   '支）血栓形',
#   '（一o支）血栓形成',
#   '硬化',
#   '微小斑块',
#   '双手符合退行性',
#   '维生素C',
#   '冈上肌部分撕裂',
#   '肱二头长头肌腱炎',
#   '维生素C',
#   'RA',
#   '滑膜增生',
#   '骨水肿',
#   '腱鞘炎',
#   '骨破坏',
#   '左右骶髂关节硬化',
#   '骶髂关节水肿',
#   '胸10-12脊柱水肿',
#   'IFANA(+)',
#   'HLAB27',
#   '骨质略疏松',
#   '软组织稍肿胀',
#   'RA',
#   '滑膜增生',
#   '骨水肿',
#   '腱鞘炎',
#   '骨破坏',
#   '右侧腘窝内囊性肿',
#   '右膝关节退行性改',
#   '髌上囊肿胀',
#   '右髋RA改变',
#   '右肩冈上肌腱撕裂',
#   '尿酸增高',
#   '不规则团块状致密影',
#   '关节见虫噬状及穿凿样骨缺损',
#   '尿胆原+',
#   '稍低密度影',
#   '周围脂肪间隙模糊',
#   '占位',
#   '胆囊结石',
#   '轻度胆囊炎',
#   '胃壁略厚',
#   '腹膜后小淋巴结',
#   '骨盆关节缘轻度骨质增生',
#   '腰椎退行性变',
#   '腰5/骶1椎间盘病变',
#   '蛋白+',
#   '胸片肺纹理增粗',
#   '前列腺轻度肿大',
#   '双膝关节退行性变',
#   '双髌股关节炎',
#   '椎间盘膨出',
#   '椎间盘变性',
#   '腰椎退变',
#   '腰4、5椎体前后滑移',
#   '腰4水平两侧小关节向椎管内增生',
#   '应椎管狭窄',
#   '椎管内少量积气',
#   '胆固醇升高',
#   '胆固醇明显升高',
#   '尿GLU',
#   '腕骨骨质略疏松',
#   '软组织稍肿胀',
#   '滑膜增生',
#   '骨水肿',
#   '腱鞘炎',
#   '骨破坏',
#   '示腰4，5椎间盘突出',
#   '镜检白细胞++',
#   '镜检红细胞+',
#   '，隐血+',
#   'HP感染',
#   'IF-ANA(-)',
#   '血小板降低',
#   '肝功能GPT升高',
#   '全身皮肤多处红斑皮损',
#   '右侧冈上肌腱局限性近全层撕裂',
#   '右膝关节骨退变',
#   '鼻甲肿大',
#   '血压升高',
#   '血糖升高',
#   '脑动脉硬化',
#   '左肾多发小结石',
#   'AVG',
#   'PAC',
#   '抗体偏高',
#   '骨量减少',
#   '左、右肩关节退行性变',
#   '颈椎退行性变',
#   '颈7两侧横突肥大',
#   '双膝髌股关节外侧间隙狭窄',
#   'IFANA(+)',
#   '左侧T2横突骨折',
#   '左侧冈上肌腱局限性近全层撕裂',
#   '左侧肩峰下滑囊炎',
#   '左侧肱二头肌长头肌腱腱鞘炎',
#   '双手骨质疏松',
#   '小囊样骨吸收',
#   '间隙变狭窄',
#   '压缩性骨折',
#   '颈椎生理曲度消失',
#   '颈椎椎体退变',
#   '滑膜增生',
#   '积液',
#   '血流信号0级',
#   '非活动期炎症',
#   '关节腔内大量积液',
#   '股骨侧大量骨水肿',
#   '脑梗塞',
#   '轻度骨质增生',
#   '退变',
#   '右膝关节有轻度骨退变',
#   '增厚肿胀',
#   '积液',
#   '空腹血糖升高',
#   '双侧基底节区缺血灶',
#   '脑白质脱髓鞘改变',
#   '血压轻度波动',
#   '房性心动过速',
#   '左肩关节及周围滑囊炎',
#   '出口粘连',
#   '轻微卡压',
#   '左肩肱骨上端前缘微软化斑',
#   '肩胛盂唇部分变性',
#   '肩区骨质增生',
#   '左膝退变',
#   '骶髂关节囊性样变',
#   '骶髂关节水肿',
#   '脂肪化',
#   '胸10-12脊柱水肿',
#   '左肾结晶',
#   '两肺纹理稍增多',
#   '双膝关节轻度骨质增生',
#   '尿血红蛋白+',
#   '双手轻度骨质疏松',
#   '左、右膝关节退行性变',
#   '两肺下叶轻度间质性改变',
#   '右肺上叶少许纤维伴胸膜增厚',
#   '骨量减少',
#   '维生素C+',
#   'HP感染',
#   '钩状肩峰',
#   '肱骨大结节增生',
#   '长头肌腱炎症',
#   'iFANA弱阳性',
#   '抗着丝点弱阳性',
#   'iFANA弱阳性',
#   '抗着丝点弱阳性',
#   '升高',
#   '双手轻度骨质疏松',
#   '两肺纹理稍增多',
#   '右上肺一可疑小粗条状影',
#   '滑膜增生',
#   '积液',
#   '第1趾血流信号1级',
#   '轻度活动炎症',
#   '滑膜增生',
#   '积液',
#   '血流信号0级',
#   '非活动期炎症',
#   '右踝关节内侧胫后肌腱腱鞘积液',
#   '胆囊小息肉',
#   '双肾结晶',
#   '（-）HLAB27(+)',
#   '骨质略疏松',
#   '软组织稍肿胀',
#   '滑膜增生',
#   '骨水肿',
#   '腱鞘炎',
#   '骨破坏',
#   '低钙',
#   '骨质疏松',
#   '房颤',
#   '快速心室率',
#   '完全性左束支波传导阻滞',
#   '白细胞增高',
#   '盆腔少量积液',
#   'T波改变',
#   '室性早搏',
#   '餐后血糖高',
#   '蛋白尿',
#   '微量蛋白尿'],
#  'm': ['33',
#   '52',
#   '1180I',
#   'U',
#   '44ss-DNA46RU',
#   '181IU',
#   '136.00IU',
#   ')1600RU',
#   '定量139IU',
#   '11.12U',
#   '22.79U',
#   '72.3U',
#   '定量139IU',
#   '11.12U',
#   '22.79U',
#   '右肩关节镜',
#   '胃镜',
#   '>200RU',
#   '913IU',
#   '913IU',
#   '<20RU',
#   '<20IU',
#   'picc'],
#  'qt': ['体检', '配药', '复诊', '复诊', '复查', '随访', '饮食控制'],
#  's': ['外伤后',
#   '外伤',
#   '外伤',
#   '外伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '流浪猫抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '抓伤',
#   '抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '抓伤',
#   '咬伤',
#   '咬伤',
#   '咬伤',
#   '抓伤',
#   '受伤',
#   '摔倒',
#   '摔倒',
#   '骨折',
#   '扭伤',
#   '外伤史',
#   '咬（抓）伤',
#   '咬（抓）伤',
#   '咬（抓）伤',
#   '咬（抓）伤',
#   '咬（抓）伤',
#   '哺乳类动物咬伤（抓伤）',
#   '咬（抓）伤',
#   '咬（抓）伤',
#   '哺乳类动物咬伤（抓伤）',
#   '咬（抓）伤',
#   '哺乳类动物咬伤（抓伤）',
#   '咬（抓）伤',
#   '哺乳类动物咬伤（抓伤）',
#   '哺乳类动物咬伤（抓伤）',
#   '右膝扭伤',
#   '左膝扭伤',
#   '左膝扭伤',
#   '左膝扭伤',
#   '牙龈痛',
#   '足外伤',
#   '外伤',
#   '哺乳类动物咬伤（抓伤）',
#   '咬（抓）伤',
#   '恶心不适',
#   '腰椎压缩性骨折',
#   '外伤',
#   '左上肢骨折'],
#  't': ['CT',
#   '骨密度',
#   '超声',
#   '血常规',
#   'HB',
#   'RBC',
#   'N',
#   'PLT',
#   'CRP',
#   'ESR',
#   '尿常规',
#   'ALT',
#   'AST',
#   '肾功能',
#   '血常规',
#   'HB',
#   'RBC',
#   'N',
#   'PLT',
#   'CRP',
#   'ESR',
#   '尿常规',
#   'ALT',
#   'AST',
#   '肾功能',
#   'X片',
#   'ANA',
#   'GPI',
#   'ANA-LIA',
#   'DNA',
#   '抗CCP',
#   'RF',
#   '体免',
#   'HLA-B',
#   '尿常规',
#   '肝肾功能',
#   '血沉',
#   'CRP',
#   '血常规',
#   '血常规',
#   'ESR',
#   'CRP',
#   '尿常规',
#   '肾功能',
#   '/ALT',
#   'AST',
#   'GGT',
#   '尿常规',
#   '血沉',
#   'CRP',
#   '血常规',
#   'MR',
#   '肾功能',
#   '/ALT',
#   'AST',
#   'GGT',
#   '尿常规',
#   '血沉',
#   'CRP',
#   '血常规',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '肌酐',
#   '葡萄糖(空腹)',
#   '尿酸',
#   '尿素氮',
#   'C反应蛋白',
#   '血红蛋白',
#   'L白细胞',
#   '抗CCP抗体',
#   'GPI',
#   'RF',
#   'IgARF',
#   'IgGRF',
#   'X片',
#   'RA',
#   '核磁共振',
#   'ESR',
#   'CRP',
#   '血尿常规',
#   'GPT',
#   'GOP',
#   'TBIL',
#   'DBIL',
#   'bndt',
#   '尿常规WBC',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   'HLA-B',
#   'CCP',
#   'RF',
#   'IFANA',
#   'GPT',
#   'GOT',
#   'BIL',
#   'DBIL',
#   'CK',
#   '抗O',
#   'X线',
#   'MRI',
#   'WB',
#   '胸片',
#   '血常规',
#   'ANA',
#   '尿微量白蛋白',
#   'RF',
#   '抗CCP',
#   'ESR',
#   'CRP',
#   '眼底',
#   '眼底',
#   'ESR',
#   'CRP',
#   '血尿常规',
#   '抗CCP抗体',
#   'GPI',
#   'RF',
#   'IgARF',
#   'IgGRF',
#   '抗O',
#   '双链DNA',
#   'IFANA',
#   'ANA',
#   'SSA',
#   'SSA',
#   '/RO',
#   '三对半',
#   'X片',
#   '核磁共振',
#   'GPT',
#   'GOP',
#   'Cr',
#   'BMDT',
#   '血沉',
#   '尿常规',
#   '血常规',
#   'CRP',
#   'ua',
#   'cr',
#   '心电图',
#   '血常规',
#   '血常规',
#   'CRP',
#   'MTX',
#   'X线',
#   '尿尿酸',
#   '膝超声',
#   '摄片',
#   'T',
#   '血常规',
#   '白细胞',
#   '中性',
#   '总胆红素',
#   '间接胆红素',
#   '肝肾功能',
#   '血常规',
#   'CRP',
#   '血沉',
#   '尿常规',
#   'PH',
#   '白细胞',
#   '隐血',
#   'ESR',
#   'CRP',
#   '血尿RT',
#   'GPT',
#   'GOT',
#   'TBIL',
#   'DBI',
#   '血尿酸',
#   'ESR',
#   '血常规',
#   '大便常规',
#   '右肩MRI',
#   'CCP',
#   'GPI',
#   'RF',
#   'hbvdna',
#   'IFANA',
#   'ANA',
#   'ESR',
#   'CRP',
#   '血尿常规',
#   'GPT',
#   'GOT',
#   'ck',
#   'Cr',
#   'BUN',
#   'BMDT',
#   'UA',
#   'WBC',
#   'PLT',
#   'LDH',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '肌酐',
#   '葡萄糖(空腹)',
#   '尿酸',
#   '尿素氮',
#   '红细胞沉降率',
#   '尿白细胞',
#   '尿红细胞',
#   '(镜',
#   'C反应蛋白',
#   '血常规',
#   '单核细胞',
#   '血尿常规',
#   '肝肾功能',
#   'ESR',
#   'CRP',
#   'T',
#   'ESR',
#   'CRP',
#   '肝肾功能',
#   'Cr',
#   '血常规',
#   'X线',
#   '检查',
#   '红细胞沉降率',
#   'C反应蛋白',
#   '血尿常规',
#   '肝肾功能',
#   '尿常规',
#   '血常规',
#   '血红蛋白',
#   'CRP',
#   'CCP',
#   'ANA',
#   'IgG',
#   '血尿常规',
#   '肝肾功能',
#   'ESR',
#   'CRP',
#   '血常规',
#   '血红蛋白',
#   '中性',
#   'CRP',
#   '肝肾功能',
#   '肌酐',
#   '尿酸',
#   '上腹部CT',
#   '摄片',
#   'MRI',
#   '血常规',
#   '中性',
#   'CRP',
#   '粪常规',
#   '粪白细胞',
#   '肝肾功能电解质',
#   'ESR',
#   '肝功能',
#   'UA',
#   '尿尿酸',
#   'RF',
#   'ESR',
#   'CRP',
#   '肝肾功能',
#   'RF',
#   'CCP',
#   'T-SPOT',
#   '二对半',
#   '血常规',
#   'WBC',
#   'Hb',
#   'PLT',
#   '尿常规',
#   'wbc',
#   'rbc',
#   'ESR',
#   'CRP',
#   '红细胞压积',
#   '血红蛋白',
#   '红细胞血红蛋白浓度',
#   '血小板压积',
#   '血小板分布宽度',
#   '血小板',
#   '红细胞总数',
#   '红细胞分布宽度',
#   'Tmax',
#   '血常规',
#   '白细胞',
#   '中性',
#   'HR',
#   '检查',
#   '尿常规',
#   'CT',
#   '头颅CT',
#   '透析',
#   'X片',
#   '血常规',
#   '肝肾功能',
#   'CRP',
#   'ESR',
#   '尿常规',
#   '血常规',
#   'ESR',
#   '腰椎CT',
#   '体检',
#   '肌酐',
#   '尿酸',
#   '尿尿酸',
#   '尿常规',
#   '尿蛋白',
#   '肾功能',
#   'Cr',
#   '尿素氮',
#   '血尿常规',
#   'WBC',
#   'HB',
#   'PLT',
#   'ESR',
#   'CRP',
#   'ESR',
#   'CRP',
#   '尿WBC',
#   'RBC',
#   '血常规',
#   'CCP',
#   'GPI',
#   'RF',
#   'IgGRF',
#   'X线',
#   'RA',
#   '核磁共振',
#   'CRP',
#   '血尿RT',
#   'GPT',
#   'GOT',
#   'CT',
#   '尿沉渣红细胞',
#   '尿沉渣白细胞',
#   '非鳞状上皮细胞',
#   '血常规',
#   'hb',
#   '尿常规',
#   'wbc',
#   'RBC',
#   'ESR',
#   'CRP',
#   'ALT',
#   'AST',
#   '肾功能',
#   '血常规',
#   'N',
#   '尿常规',
#   'ESR',
#   'CRP',
#   '要求/幽门螺杆菌检查',
#   '呼气试验',
#   'iFANA',
#   '血钙',
#   'CK',
#   'ASO',
#   'GPI',
#   'CCP',
#   'ANA-LIA',
#   '血尿常规',
#   'CRP',
#   'ESR',
#   'RF',
#   'CRP',
#   'ESR',
#   'RF',
#   'ds-DNA',
#   '抗SSA',
#   '抗SSB',
#   '抗U',
#   'C',
#   'IgG',
#   'IgA',
#   '无痛胃镜检查',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '红细胞沉降率',
#   'C反应蛋白',
#   '血小板',
#   '白细胞总数',
#   '尿常规',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '红细胞沉降率',
#   'C反应蛋白',
#   '血小板',
#   '白细胞总数',
#   '尿常规',
#   'X片',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '肌酐',
#   '尿酸',
#   '尿素氮',
#   'C反应蛋白',
#   '中性粒细胞',
#   '白细胞总数',
#   '红细胞沉降率',
#   '肝肾功能',
#   '碱性磷酸酶',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '肌酐',
#   '尿酸',
#   '尿Rt',
#   'pH',
#   'HLA-B',
#   'MRI',
#   'ESR',
#   'CRP',
#   'MRI',
#   '红细胞沉降率',
#   'C反应蛋白',
#   '血小板',
#   '红细胞总数',
#   '白细胞总数',
#   'L骨密度',
#   '红细胞沉降率',
#   'C反应蛋白',
#   '血小板',
#   '红细胞总数',
#   '白细胞总数',
#   'L骨密度',
#   'HLA-B',
#   'C反应蛋白',
#   '红细胞沉降率',
#   'IgM型类风湿因子',
#   '抗环瓜氨酸肽抗体',
#   'CCP',
#   'X线',
#   '血常规',
#   'wbc',
#   'CRP',
#   '血沉',
#   '尿常规',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   '肝肾功能',
#   '超声',
#   '血常规',
#   'wbc',
#   'CRP',
#   '血沉',
#   '尿常规',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   '肝肾功能',
#   '血沉',
#   '肝肾功能',
#   'CRP',
#   '血常规',
#   'wbc',
#   '血常规',
#   'wbc',
#   'N',
#   '尿常规',
#   '尿白细胞',
#   'ESR',
#   'CRP',
#   '肝肾功能',
#   '血尿常规',
#   'ESRMM',
#   'CRP',
#   '肝肾功能',
#   '肝功能',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   'C反应蛋白',
#   '血小板',
#   '红细胞总数',
#   '白细胞总数',
#   '骨扫描',
#   'B超',
#   '动态血压',
#   '动态心电图',
#   'BPM',
#   '肌酐',
#   '血糖',
#   '体温',
#   '体温',
#   '体检',
#   '体检',
#   '，最高T',
#   '甲功',
#   'TSH',
#   '骨密度',
#   'X片',
#   '肝肾功能',
#   '电解质',
#   '尿MA',
#   '尿Rt',
#   'RF',
#   '体免',
#   'GPI',
#   'CCP',
#   'ESR',
#   'CRP',
#   '血Rt',
#   'HLA-B27',
#   'ifANA',
#   'ANA谱',
#   'RF',
#   '血尿常规',
#   '肝肾功能',
#   '免疫学指标',
#   'X片',
#   'CT',
#   '，B超',
#   'IgMRF',
#   'IgARF',
#   'IgGRF',
#   'CCP',
#   '血常规',
#   'PLT',
#   '尿常规',
#   'ESR',
#   'CRP',
#   'ALT',
#   'AST',
#   'C反应蛋白',
#   '红细胞压积',
#   '血红蛋白',
#   '中性粒细胞绝对数',
#   '中性粒细胞',
#   '血小板',
#   '红细胞总数',
#   '白细胞总数',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '肌酐',
#   '葡萄糖(空腹)',
#   '尿酸',
#   '尿素氮',
#   '红细胞沉降率',
#   'C反应蛋白',
#   '血红蛋白',
#   '血小板',
#   '红细胞总数',
#   '白细胞总数',
#   '肾功能',
#   '血尿酸',
#   '肌酐',
#   'FPG',
#   'UA',
#   'BUN',
#   'SCr',
#   'ALT',
#   'AST',
#   '血尿常规',
#   'ESR33',
#   'CRP',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   'WBC',
#   'ESR',
#   'CRP',
#   'GPT',
#   'GOT',
#   '肾功能',
#   'X线',
#   '检查',
#   'RF',
#   'ESR',
#   'X线',
#   'IgMRF',
#   'IgARF',
#   'IgGRF',
#   'CCP',
#   '血常规',
#   'ESR',
#   'CRP',
#   '尿常规',
#   'WBC',
#   '尿白细胞酯酶',
#   '血常规',
#   'CRP',
#   'ESR',
#   '尿尿酸',
#   '尿常规',
#   '肝肾功能',
#   '尿常规',
#   '谷草',
#   '谷丙',
#   '空腹血糖',
#   '血尿酸',
#   '血常规',
#   'CRP',
#   'ESR',
#   '尿尿酸',
#   '裸眼视力',
#   'X线',
#   'MR',
#   '头颅CT',
#   'X线',
#   'CCP',
#   'GPI',
#   'RA',
#   'HLA-B27',
#   'IFANA',
#   'ANA',
#   'SSA',
#   'SSA',
#   'RO52',
#   'HLA-B27',
#   'ACL',
#   '双链DNA',
#   '三对半',
#   'HBV-DNA5',
#   'X线',
#   'ESR',
#   'CRP',
#   '血尿RT',
#   'GPT',
#   'GOT',
#   '尿RT',
#   'WBC',
#   'FPG',
#   'SCr',
#   'ALT',
#   'AST',
#   'CRP',
#   'ESR',
#   '血尿常规',
#   'SCr',
#   'UA',
#   '肌酐',
#   '肾功能',
#   '肌酐',
#   '尿酸',
#   '尿素',
#   'ALT',
#   'AST',
#   '右膝CT',
#   'MRI',
#   'ESR',
#   '血尿常规',
#   'CRP',
#   '肝功能',
#   'UA',
#   '肝肾功能',
#   '尿常规',
#   '尿尿酸',
#   '血常规',
#   '白细胞',
#   '中性',
#   'CRP',
#   '血压',
#   '血压',
#   '身高',
#   '体重',
#   '腰围',
#   '臀围',
#   '血糖',
#   '头颅CT',
#   'MRI检查',
#   '裸眼视力',
#   'ESR',
#   'hsCRP',
#   '血常规',
#   'Hb',
#   '尿常规',
#   '肝功能',
#   'ESR',
#   'hsCRP',
#   '血常规',
#   'Hb',
#   '尿常规',
#   '肝功能',
#   '白细胞',
#   '心电图',
#   '血尿常规',
#   '肝肾功能',
#   '抗CCP',
#   '类风湿因子',
#   '抗核抗体',
#   '血常规',
#   '肝肾功正常',
#   '左肩MRI',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   '血常规',
#   'ESR',
#   'CRP',
#   '血尿常规',
#   'CRP',
#   'ESR',
#   'SCr',
#   'ALT',
#   'AST',
#   'T',
#   'X片',
#   '血常规',
#   '白细胞',
#   '肾功能',
#   '尿酸',
#   '肝功能',
#   '谷草',
#   'CCP',
#   'RF',
#   'HLA-B27',
#   'RF',
#   '三对半',
#   'X线',
#   'MRI',
#   'ESR',
#   'CRP',
#   'GPT',
#   'GOT',
#   'CK',
#   '血尿RT',
#   'PLT',
#   'BNDT',
#   'UA',
#   'UA',
#   'B超',
#   '血常规',
#   '查体',
#   '尿常规',
#   'ESR',
#   '血常规',
#   'CRP',
#   'T',
#   'T',
#   'ALT',
#   'AST',
#   'ESR',
#   '血常规',
#   'RBC',
#   'PLT',
#   '98，N',
#   'CRP',
#   '尿常规',
#   'x-ray',
#   '胸片',
#   'RF',
#   'ANA',
#   '双链DNA',
#   'ESR',
#   'CRP',
#   '血尿RT',
#   'GPT',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   '血常规',
#   'CRP',
#   '血沉',
#   '尿常规',
#   '血常规',
#   'RBC',
#   'HB',
#   'N',
#   'CRP',
#   'ESR',
#   '尿常规',
#   'ALT',
#   'AST',
#   '肾功能',
#   'HB',
#   'RBC',
#   'N',
#   'PLT',
#   'CRP',
#   'ESR',
#   '尿常规',
#   'ALT',
#   'AST',
#   '肾功能',
#   'ESR',
#   'CRP',
#   '血尿RT',
#   'GPT',
#   'GOT',
#   'ESO',
#   'RF',
#   'CCP',
#   'UA',
#   'ifANA',
#   'AKA',
#   'CCP',
#   'CRP',
#   '血Rt',
#   'WBC',
#   'N',
#   'PLT',
#   'Hb',
#   'ESR',
#   '双手正位片',
#   '双膝正侧位片',
#   '胸部CT',
#   '骨密度',
#   '肝肾功能',
#   '电解质',
#   '尿Rt',
#   '尿MA',
#   '血常规',
#   'RBC',
#   '尿常规',
#   'CRP',
#   '肝肾',
#   '电解质',
#   'ESR',
#   '血沉',
#   'CRP',
#   '血常规',
#   'RBC',
#   'Hb',
#   'PLT',
#   'N',
#   '尿常规',
#   '裸眼视力',
#   '查眼底',
#   'X线片',
#   'MR',
#   '尿酸',
#   '肌酐',
#   '血尿常规',
#   'CRP',
#   'ESR',
#   'HLA-B',
#   'ANA-LIA',
#   'CCP',
#   'RF',
#   '血尿常规',
#   'CRP',
#   'ESR',
#   'HLA-B',
#   'ANA-LIA',
#   'CCP',
#   'RF',
#   '类风湿因子IgM',
#   'IgG',
#   'X片',
#   'CT',
#   '血红蛋白',
#   '红细胞总数',
#   'C反应蛋白',
#   '红细胞沉降率',
#   '肝肾功能',
#   'RF',
#   '胃镜检查',
#   '胸片',
#   'C反应蛋白',
#   '血常规',
#   '淋巴细胞',
#   '单核细胞绝对数',
#   '中性粒细胞绝对数',
#   '中性粒细胞',
#   '血小板分布宽度',
#   '白细胞总数',
#   '血常规',
#   'CRP',
#   '尿常规',
#   'ESR',
#   'GPT',
#   'GOT',
#   '血常规',
#   'N',
#   'CRP',
#   'ESR',
#   '尿常规',
#   '肝肾功能',
#   'CK',
#   '血常规',
#   'CRP',
#   '尿常规',
#   'ESR',
#   'GPT',
#   'GOT',
#   '血常规',
#   'N',
#   'CRP',
#   'ESR',
#   '尿常规',
#   '肝肾功能',
#   'CK',
#   '血常规',
#   '肝肾功能',
#   '血沉',
#   '尿常规',
#   '血常规',
#   '肝肾功能',
#   '血沉',
#   '尿常规',
#   '血尿酸',
#   '右足超声',
#   '右踝超声',
#   '血常规',
#   'CRP',
#   'ESR',
#   '尿常规',
#   '肾功能',
#   '血尿酸',
#   '肌酐',
#   '谷丙',
#   '谷草',
#   '尿尿酸',
#   'B超',
#   '血常规',
#   'CRP',
#   '谷丙转氨酶',
#   '谷草转氨酶',
#   '肌酐',
#   '尿酸',
#   '尿素氮',
#   '抗环瓜氨酸肽抗体',
#   ')',
#   'IgM型类风湿因子',
#   '红细胞沉降率',
#   'ESR',
#   'CRP',
#   '血尿常规',
#   '抗CCP抗体',
#   'GPI',
#   '抗O',
#   '双链DNA',
#   '<->IFANA',
#   'ANA',
#   '，三对半',
#   'X片',
#   '核磁共振',
#   'GPT',
#   'GOP',
#   'Cr',
#   '血小板',
#   '血常规',
#   'RF',
#   '肌酐',
#   '血沉',
#   '血尿常规',
#   'ESR',
#   'CRP',
#   '体检',
#   '血压',
#   '空腹血糖',
#   '糖化血红蛋白',
#   '体检',
#   '电解质检查',
#   'fg',
#   '血糖',
#   '体检',
#   '血压',
#   '血压',
#   '血常规',
#   '宫颈检查',
#   'B超',
#   '摄片',
#   '血压',
#   '血糖',
#   '心电图',
#   '超声检查',
#   '空腹血糖',
#   '体温',
#   '空腹血糖',
#   '血压',
#   'ACR'],
#  'w': ['腰3/4',
#   '腰4/5',
#   '腰5',
#   '骶1',
#   '腰椎',
#   'T=-2.1，max-2.6，股骨T',
#   '右小腿腓静脉',
#   '左小腿',
#   '腓静脉',
#   '左侧小腿肌内静脉丛',
#   '双下肢动脉',
#   '双下肢',
#   '深静脉',
#   '双眼',
#   '双眼',
#   '颈',
#   '左膝关节',
#   '双手部分小关节',
#   '双手DIP关节',
#   '右手第3PIP关节',
#   '关节',
#   '腰部',
#   '舌',
#   '右膝',
#   '臀部右侧',
#   '四肢关节',
#   '10mg',
#   '双手指骨骨端',
#   '腕骨',
#   '双手近指关节',
#   '双腕关节间隙',
#   '双膝关节',
#   '左侧腹股沟',
#   '多关节',
#   '左足',
#   '右肘',
#   '胸椎',
#   '颈部',
#   '左髋',
#   '四肢关节',
#   '左右足DIPPIP',
#   'MIP',
#   '关节',
#   '左右膝关节',
#   '左右踝',
#   '双足跟',
#   '右肩关节',
#   '四肢关节',
#   '双足趾',
#   '膝关节',
#   '双足趾软组织',
#   '双手',
#   '右肾内',
#   '右膝关节',
#   '右膝关节',
#   '骨盆诸骨',
#   '双手指',
#   '肩',
#   '膝',
#   '：/L3/4',
#   'L4/5',
#   'L5/S1',
#   'L5/S1',
#   '腰背部',
#   '胸肋关节',
#   '关节',
#   '双手指骨骨端',
#   '双手近指关节',
#   '双腕关节间隙',
#   '双手指关节',
#   '双膝',
#   '双肩',
#   '双踝',
#   '双手近端指间关节',
#   '双腕关节',
#   '双膝',
#   '双足趾关节',
#   '双眼',
#   '双膝',
#   '关节',
#   'T6',
#   'T8',
#   '全身皮肤',
#   '双侧骶髂关节',
#   '腰椎1',
#   '腰椎2',
#   '腰椎1',
#   '腰椎2',
#   '右眼',
#   '关节',
#   '双膝关节',
#   '关节',
#   '右肩关节',
#   '双膝关节',
#   '右踝',
#   '颈项',
#   '肩',
#   '背部',
#   '胃部',
#   '腹部',
#   '左眼',
#   '左踝关节',
#   '面部',
#   '肩部',
#   '颈项',
#   '肩',
#   '背部',
#   '颈项',
#   '肩',
#   '背部',
#   '牙齿',
#   '鼻翼',
#   '口角',
#   '上腹',
#   '双肩',
#   '双肩胛区',
#   '远端指间关节',
#   '右肩关节',
#   '双手指',
#   '双手腕',
#   '双膝',
#   '双足',
#   '指间关节',
#   '、腕骨间关节',
#   '关节',
#   'T11',
#   'T12',
#   '双手',
#   '双膝',
#   '双肩',
#   '颈部',
#   '下颌关节',
#   '右膝扭伤',
#   '右膝扭伤',
#   '双肩',
#   '双膝',
#   '双足跟',
#   '双膝',
#   '双踝关节',
#   '双腕',
#   '双肩',
#   '双足MTP关节',
#   '双手',
#   '双足',
#   '双手指',
#   '双手腕',
#   '双膝',
#   '双足',
#   '右踝',
#   '左侧踝关节',
#   '左侧踝关节周围肌腱',
#   '右足第五跖骨基底部',
#   '四肢关节',
#   '右膝',
#   '右膝关节囊',
#   '髌上囊',
#   '双眼',
#   '双手指关节',
#   '双腕',
#   '双肘',
#   '双肩',
#   '双膝',
#   '双踝',
#   '双足',
#   '右手拇指',
#   '中指',
#   '肩腱袖腱鞘',
#   '\ufeff左膝',
#   '、右足趾关节',
#   '左足第一趾关节',
#   '右肾',
#   '膀胱',
#   '双侧输尿管',
#   '四肢多关节',
#   '左踝',
#   '左膝',
#   '左右手',
#   'DIP',
#   'PIP',
#   'MIP',
#   '左右腕关节',
#   '左右肘关节',
#   '左右膝关节',
#   '左右踝',
#   '左右趾',
#   '左右肩关节',
#   '腰背',
#   '四肢多关节',
#   '关节',
#   '左右手',
#   'DIP',
#   'PIP',
#   'MIP',
#   '左右腕关节',
#   '左右肘关节',
#   '左右膝关节',
#   '左右趾关节',
#   '左右肩关节',
#   '右肩关节',
#   '双手MCP',
#   '双PIP',
#   '双DIP',
#   '双腕',
#   '双肘',
#   '双肩',
#   '双髋',
#   '双膝',
#   '双踝',
#   '双足趾',
#   '双膝关节',
#   '双肩',
#   '双髋',
#   '腰痛',
#   '关节',
#   '右肘',
#   '颈部',
#   '双眼',
#   '胃脘',
#   '胃脘',
#   '左肩峰',
#   '冈上肌',
#   '肱二头肌',
#   '左手',
#   '双肩',
#   '双膝关节',
#   '双手指关节',
#   '双腕',
#   '双肘',
#   '双踝',
#   '双足MTP',
#   '右肩',
#   '双手掌指关节',
#   '近端指间关节',
#   '双肩',
#   '双肘',
#   '双膝',
#   '双踝',
#   '双膝关节',
#   '脐周',
#   '关节',
#   '关节',
#   '关节',
#   '左膝',
#   '双踝',
#   '右足跖趾关节',
#   '右侧踝关节',
#   '双手指DIP',
#   '双手指骨骨端',
#   '腕骨',
#   '双手近指关节',
#   '双腕关节间隙',
#   '左腕',
#   '右肩',
#   '四肢',
#   '牙齿',
#   '四肢',
#   '甲状腺',
#   '面部',
#   '面部',
#   '四肢'],
#  'yc': ['质红',
#   '尖红',
#   '苔薄白',
#   '裂痕',
#   '，脉浮数',
#   '双足拇外翻',
#   '双足拇外翻',
#   '面色黧黑',
#   '拄拐入病房',
#   '跛行',
#   '乳房结节'],
#  'yw': ['益赛普',
#   '复方血栓通胶囊',
#   'MTX',
#   'LEF',
#   '艾拉莫德',
#   '美卓乐',
#   'MTX',
#   'LEF',
#   '艾拉莫德',
#   '美卓乐',
#   '来氟米特',
#   '正清风痛宁',
#   'MTX',
#   '美洛昔康',
#   '+羟基氯喹',
#   '+氨基葡萄糖',
#   'RA药物',
#   '中药汤药',
#   '抗感冒药物',
#   '福米特',
#   '正清风痛宁',
#   '非布司他',
#   'sasp',
#   '双氯酚',
#   'MTX',
#   '中药',
#   '蒙脱石散',
#   '别嘌呤',
#   '西比灵',
#   '抗生素',
#   '感冒药',
#   '抗生素',
#   '感冒药',
#   '甘精胰岛素',
#   '阿卡波糖',
#   '抗生素',
#   '感冒药',
#   'RA药物',
#   '硫酸氨基葡萄糖',
#   '艾拉莫得',
#   '昆仙胶囊',
#   '强的松',
#   '乐松',
#   '氨基葡萄糖胶囊',
#   '阿法骨化醇片',
#   '文胶囊',
#   '氧胆酸胶囊',
#   '美拉唑',
#   '钙尔奇D',
#   'MTX',
#   '黄连素',
#   '蒙脱石散',
#   '尪痹片',
#   '咳嗽药水',
#   '含片',
#   '活血类药物',
#   '奥氮平',
#   '利培酮',
#   '奥氮平',
#   '利培酮',
#   '助眠药物',
#   '莱士普',
#   'RA药物',
#   '益塞普',
#   '强的松',
#   '青霉胺',
#   '雷公藤',
#   '西乐葆',
#   '强的松',
#   '青霉胺',
#   '雷公藤',
#   '西乐葆',
#   '强的松',
#   'MTX',
#   '强的松',
#   'LEF',
#   '帕夫林',
#   'MTX',
#   '强的松',
#   'LEF',
#   '帕夫林',
#   '抗CCP',
#   'RA药物',
#   'RA药物',
#   '依托考昔',
#   '本溴马龙',
#   'RA药物',
#   '艾拉莫德',
#   '爱若华',
#   '。服用/英太青',
#   'MTX',
#   '青霉胺',
#   '感冒药物',
#   '克感敏',
#   '开同',
#   '拜心同',
#   '立普妥',
#   '得每通',
#   '降糖药',
#   '他定',
#   '止痛药',
#   '消炎药',
#   '骨康胶囊',
#   '骨化三醇',
#   '强的松',
#   '雷公藤',
#   '益赛普',
#   'SASP',
#   '正清风痛宁',
#   '乐松',
#   '保肾康',
#   '迈之灵',
#   '西乐葆',
#   '碳酸氢钠片',
#   'MTX',
#   '雷公藤',
#   'MTX',
#   'LEF',
#   '强骨胶囊',
#   '双乌风湿合剂',
#   '扶他林',
#   '头孢',
#   '波立维',
#   'RA药物',
#   '美卓乐',
#   'RA药物',
#   '强的松',
#   '非布司他',
#   '安神药',
#   '科素亚',
#   '玄宁',
#   '琥珀酸美托洛尔缓释片',
#   '中药',
#   '消炎止痛药物',
#   '西乐葆',
#   '芬必得',
#   'SAS',
#   '反应停',
#   '中药',
#   '益赛普',
#   '甲氨喋啶片',
#   '塞来昔布胶囊',
#   '西乐葆',
#   '益赛普',
#   '妥抒',
#   '雷贝拉唑钠肠溶片',
#   '钙尔奇',
#   '叶酸片',
#   '强的松',
#   '激素',
#   '美卓乐青霉胺',
#   'MTX',
#   '激素MGMST',
#   'MTX',
#   '雷公藤',
#   '秋水仙碱',
#   '中草药',
#   '美卓乐',
#   '美卓乐',
#   '复方风湿宁胶囊',
#   '双氯芬酸钠缓释胶囊',
#   '头孢丙烯',
#   'MTX',
#   'HCQ',
#   '叶酸片',
#   '美洛昔康',
#   'N',
#   'MTX',
#   'HCQ',
#   '叶酸片',
#   '美洛昔康',
#   'N',
#   'MTX',
#   '青霉胺',
#   '强的松',
#   'LEF',
#   '艾得辛',
#   '钙尔奇D',
#   '达美康',
#   '来得时',
#   '二甲',
#   '降压药',
#   '安定',
#   '消炎药',
#   '降糖药',
#   '外用药膏',
#   '黄葵',
#   '胰岛素'],
#  'zl': ['复诊',
#   '服药',
#   '复诊',
#   '服药',
#   '复诊',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '复诊',
#   '配药',
#   '服药',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '用药',
#   '服药',
#   '复诊',
#   '药后',
#   '复诊',
#   '复诊',
#   '服药',
#   '复诊',
#   '复诊',
#   'RA药物',
#   '复诊',
#   '服药',
#   '服药',
#   '配药',
#   '复诊',
#   '复诊',
#   '服药',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '服药',
#   '配药',
#   '配药',
#   '复诊',
#   '补液治疗',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '伤口自行冲洗',
#   '伤口自行冲洗',
#   '伤口自行冲洗',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '伤口自行冲洗',
#   '复诊',
#   '复诊',
#   '伤口自行冲洗',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '服药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '补液',
#   '配药',
#   '复诊',
#   '配药',
#   '服药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '复诊',
#   '配药',
#   '服药',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '复诊',
#   '复诊',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '换药',
#   '复诊',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '，服药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '复诊',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '服药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '调整药物',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '服药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '配药',
#   '用药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '降糖药',
#   '复诊',
#   '降糖药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '配药',
#   '配药',
#   '复诊',
#   'RA药物',
#   '复诊',
#   'RA药物',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '保肝治疗',
#   '复诊',
#   '降糖药',
#   '服药',
#   '配药',
#   '服药',
#   '服药',
#   '配药',
#   '复诊配药',
#   '中药',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '胆汁反流配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '服药',
#   '续药',
#   '药物',
#   '服药',
#   '口服药物',
#   '配药',
#   '补牙',
#   '配药',
#   '复诊',
#   '服药',
#   '求治',
#   '复诊',
#   '服药',
#   '用药',
#   '复诊',
#   '用药',
#   '调整用药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '补液',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '补液',
#   '复诊',
#   '补液',
#   '复诊',
#   '用药',
#   '伤口自行冲洗',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '用药',
#   '补液',
#   '复诊',
#   '复诊',
#   '复诊',
#   '伤口自行冲洗',
#   '复诊',
#   '补液',
#   '补液',
#   '伤口自行冲洗',
#   '复诊',
#   '复诊',
#   '复查',
#   '复诊',
#   '复诊',
#   '药物',
#   '复诊',
#   '用药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '口服中草药',
#   '复诊',
#   '复诊',
#   'RA药物',
#   '配药',
#   '复诊',
#   '服药',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '用药',
#   '服药',
#   '配药',
#   '口服药物',
#   '降糖治疗',
#   '长期服药',
#   '配药',
#   '药物治疗',
#   '复诊',
#   '复诊',
#   '复诊',
#   '。服药',
#   '复诊',
#   '配药',
#   '复诊',
#   '配药',
#   '复诊',
#   '行胆囊炎手术',
#   '邮购药',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '用药',
#   '伤口自行冲洗',
#   '复诊',
#   '复诊',
#   '配药',
#   'RA药物',
#   '复诊',
#   '消炎止痛治疗',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '用药',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '用药',
#   '复诊',
#   '复诊',
#   '服药',
#   '药物治疗',
#   '药物治疗',
#   '复诊',
#   '配药',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '配药',
#   '复诊',
#   '服药',
#   '复诊',
#   '用药',
#   '配药',
#   '复诊',
#   '复诊',
#   '保守治疗',
#   '服药',
#   '配药',
#   '感冒药物',
#   '复诊',
#   '复诊',
#   '复诊',
#   '复诊',
#   '降糖药物',
#   '复诊',
#   '配药',
#   '配药',
#   '维持性血透',
#   '配药',
#   '复查',
#   '配药',
#   '复查',
#   '换药',
#   '复诊',
#   '配药',
#   '口服抗生素',
#   '治疗',
#   '复诊',
#   '配药',
#   '复诊',
#   '服药',
#   '用药',
#   '抗感染治疗',
#   '用药',
#   '服药',
#   '复诊',
#   '配药',
#   '服药',
#   '复诊',
#   '配药',
#   '配药',
#   '服药',
#   '复诊',
#   '用药',
#   '配药',
#   '用药',
#   '服药',
#   '复诊',
#   '配药',
#   '配药',
#   '复诊',
#   '配药',
#   '续药',
#   '服药',
#   '服药',
#   '服药',
#   '服药',
#   '复诊',
#   '服药',
#   '患者按时',
#   '复诊',
#   '胃部不适',
#   '注射治疗',
#   '复诊',
#   '服药',
#   '用药',
#   '配药',
#   '服药',
#   '服药',
#   '服药',
#   '复诊',
#   '复诊',
#   '配药',
#   '配药'],
#  'zs': ['双下肢疼痛畏冷',
#   '肩痛',
#   '双上肢麻木',
#   '干涩',
#   '异物感',
#   '干涩',
#   '异物感',
#   '痛',
#   '活动受限',
#   '右侧腰腿痛',
#   '陂行',
#   '腰部酸痛',
#   '泌尿道感染',
#   '小便频',
#   '腰酸',
#   '活动欠利',
#   '咳嗽',
#   '咽痛',
#   '少痰',
#   '活动性疼痛',
#   '绞索',
#   '活动欠利',
#   '咳嗽',
#   '咽痛',
#   '少痰',
#   '咳嗽咽痛',
#   '咳嗽',
#   '咳痰',
#   '痰少',
#   '咽痛',
#   '疼痛',
#   '骨性肿大',
#   '肿痛',
#   '骨性肿大',
#   '左腕疼痛',
#   '双手指麻木',
#   '睡眠差',
#   '肿痛',
#   '晨僵',
#   '乏力',
#   '关节僵',
#   '关节怕冷怕风',
#   '大便欠畅',
#   '大便欠畅',
#   '肛门作胀',
#   '有便意',
#   '月经量少',
#   '腰酸',
#   '经期明显',
#   '口苦口粘',
#   '大便稀偏',
#   '睡眠梦多',
#   '左肩关节疼痛',
#   '左肩关节疼痛',
#   '夜间疼痛',
#   '右腕关节肿痛',
#   '右腕关节肿痛',
#   '弯腰活动受限',
#   '弯腰活动受限',
#   '腰部酸软',
#   '行走乏力',
#   '酸痛',
#   '酸胀',
#   '翻身活动欠利',
#   '便秘',
#   '睡眠障碍',
#   '入睡困难',
#   '早醒',
#   '失眠',
#   '双膝疼痛',
#   '乏力',
#   '关节僵硬',
#   '关节怕冷怕风',
#   '腹泻',
#   '水样便',
#   '胃脘部胀痛',
#   '多关节肿痛',
#   '上腹饱胀',
#   '上腹饱胀嗳气',
#   '鼻塞',
#   '流涕',
#   '咽痛',
#   '痰少',
#   '咽痒',
#   '头晕',
#   '颈部不适',
#   '左上肢放射痛',
#   '胸骨后不适',
#   '关节疼痛',
#   '活动不利',
#   '右下肢酸痛',
#   '左足底疼痛',
#   '胸闷',
#   '咳嗽',
#   '黄痰',
#   '心悸',
#   '睡眠较差',
#   '头胀',
#   '头晕',
#   '口粘',
#   '口干',
#   '咳嗽',
#   '阵发性咳嗽',
#   '双手关节疼痛',
#   '双手关节肿痛',
#   '双眼干涩',
#   '关节痛',
#   '乏力',
#   '头晕',
#   '左肩疼痛',
#   '双膝肿痛',
#   '关节痛',
#   '疼痛',
#   '活动受限',
#   '左足趾肿痛',
#   '关节肿痛',
#   '流涕',
#   '流涕',
#   '清涕',
#   '乏力感',
#   '多关节肿痛',
#   '下腹部疼痛',
#   '下腹部疼痛',
#   '双足第一跖趾关节红肿痛',
#   '右足第一跖趾关节红肿痛',
#   '肿痛',
#   '晨僵',
#   '中上腹不适',
#   '肿胀疼痛',
#   '腰腿关节酸痛',
#   '腰痛',
#   '右踝关节肿痛',
#   '右踝关节肿痛',
#   '右膝关节肿胀疼痛',
#   '右膝扭伤',
#   '咽痛',
#   '咽痛',
#   '发热',
#   '左踝关节疼痛',
#   '疼痛',
#   '晨僵',
#   '左右趾关节痛',
#   '疼痛肿胀',
#   '晨僵',
#   '丘疹',
#   '、斑疹',
#   '皮损',
#   '四肢肿胀',
#   '左肩关节疼痛',
#   '腰腿部疼痛',
#   '右膝关节酸痛',
#   '久坐站立困难',
#   '咽喉不利',
#   '咽痛',
#   '轻度发热',
#   '发热',
#   '纳食较差',
#   '呕吐腹泻',
#   '周身乏力',
#   '呕吐',
#   '四肢多关节肿痛',
#   '多关节肿痛',
#   '晨僵',
#   '关节肿痛',
#   '行动不利',
#   '关节肿痛',
#   '晨僵',
#   '单关节红肿热痛',
#   '左足第一跖趾关节红肿热痛',
#   '腹泻',
#   '腹泻',
#   '水样泻',
#   '呕吐症',
#   '右肩疼痛',
#   '疼痛',
#   '夜间疼痛',
#   '腹胀',
#   '隐痛',
#   '泛酸',
#   '多矢气',
#   '肠鸣',
#   '关节疼痛',
#   '咳嗽',
#   '右肘关节疼痛',
#   '神疲乏力',
#   '腰膝酸楚',
#   '头晕',
#   '耳鸣',
#   '心悸气短',
#   '纳谷不馨',
#   '畏寒怯冷',
#   '心烦潮热',
#   '口干',
#   '咽燥',
#   '遗精',
#   '滑泄',
#   '月经不调',
#   '停经',
#   '双下肢无力',
#   '双下肢踏棉感',
#   '左膝疼痛',
#   '左膝关节疼痛',
#   '咳嗽',
#   '喷嚏',
#   '左膝肿痛',
#   '左膝疼痛',
#   '左膝关节疼痛',
#   '咳嗽',
#   '喷嚏',
#   '左膝疼痛',
#   '左膝关节疼痛',
#   '咳嗽',
#   '喷嚏',
#   '颈痛',
#   '活动受限',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '乏力',
#   '虚汗出',
#   '恶心',
#   '咽痛',
#   '右足',
#   '肿痛',
#   '晨',
#   '疼痛',
#   '晨僵',
#   '左右',
#   '心悸',
#   '胸闷不适',
#   '肢体乏力',
#   '多关节肿痛',
#   '晨僵',
#   '多饮',
#   '多尿',
#   '多食',
#   '头痛',
#   '头痛',
#   '头痛',
#   '呕吐',
#   '咽痛',
#   '咽痛',
#   '咳嗽',
#   '咳痰',
#   '鼻塞流涕',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咽痛',
#   '发热',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '周身酸痛',
#   '流涕',
#   '咳嗽',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '周身酸痛',
#   '手麻',
#   '抓伤',
#   '抓伤',
#   '抓伤',
#   '发热',
#   '畏寒',
#   '发热',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咽痛',
#   '周身酸痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咽痛',
#   '发热',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '周身酸痛',
#   '发热',
#   '低热',
#   '咳嗽',
#   '痰少',
#   '流涕',
#   '脓涕',
#   '头痛',
#   '头胀酸痛',
#   '恶心',
#   '呕吐',
#   '呕吐胃内物物',
#   '恶心',
#   '上腹痛',
#   '食入即吐',
#   '恶心',
#   '呕吐',
#   '呕吐胃内物物',
#   '恶心',
#   '上腹痛',
#   '食入即吐',
#   '活动受限',
#   '双膝关节疼痛不适',
#   '后下肢足趾关节肿痛',
#   '红',
#   '肿',
#   '热',
#   '痛',
#   '疼痛剧烈',
#   '不能下地',
#   '关节痛',
#   '夜间双足肿胀',
#   '双手指关节肿痛',
#   '皮肤',
#   '紧绷感',
#   '遇冷发紫发白',
#   '麻木感',
#   '四肢多关节肿痛',
#   '四肢多关节肿痛',
#   '左手掌指关节肿痛',
#   '上腹痛',
#   '右踝肿痛不适',
#   '咽痛',
#   '双膝关节疼痛',
#   '疼痛',
#   '活动不利',
#   '疼痛',
#   '活动不利',
#   '左上腹痛',
#   '左侧腹痛',
#   '隐痛',
#   '背部放射痛',
#   '腰骶部疼痛不适',
#   '疼痛',
#   '腹泻',
#   '腹泻',
#   '水样便',
#   '大便色黄',
#   '腹泻',
#   '腹泻',
#   '多/关节肿痛',
#   '咳嗽',
#   '干咳',
#   '眠差',
#   '四肢多关节痛',
#   '腹胀',
#   '周身酸痛',
#   '发热',
#   '外跑',
#   '夜眠仍差',
#   '无法行走',
#   '夜间睡眠欠佳',
#   '尿急',
#   '夜眠差',
#   '昏昏沉沉',
#   '讲话不清',
#   '乏力',
#   '生活疏懒',
#   '胃纳下降',
#   '便秘',
#   '夜眠差',
#   '喉头发紧',
#   '透不过气',
#   '烦躁不安',
#   '不想与人交流',
#   '疑病',
#   '躯体不适',
#   '怀疑自己有躯体疾病',
#   '心里一直放不下',
#   '血尿',
#   '疑病',
#   '眠差',
#   '夜眠差',
#   '无故紧张',
#   '担心',
#   '烦躁不安',
#   '夜眠差',
#   '进行性记忆力减退',
#   '行为紊乱',
#   '记忆力的减退',
#   '容易忘记',
#   '，经常',
#   '唠叨往事',
#   '生活逐渐不能自理',
#   '记忆减退',
#   '言行紊乱',
#   '脾气大',
#   '睡眠时好时坏',
#   '情绪不稳定',
#   '焦虑不安',
#   '在家不愿出门',
#   '对人依赖',
#   '耳闻人语',
#   '胡言乱语',
#   '行为紊乱',
#   '夜眠差',
#   '言语性幻听',
#   '猜疑',
#   '心里想的不说别人都知道',
#   '痛苦不堪',
#   '夜眠差',
#   '夜眠差',
#   '夜眠差',
#   '入睡困难',
#   '生活代理',
#   '大小便代理',
#   '白天感乏力',
#   '头颈强',
#   '夜眠差',
#   '睡眠差',
#   '情绪显低',
#   '不愿意做事',
#   '妄想',
#   '夜眠差',
#   '焦虑',
#   '紧张',
#   '双膝关节疼痛',
#   '猜疑',
#   '兴趣索然',
#   '纳差',
#   '右膝关节肿胀',
#   '右乳外上象限红肿热痛',
#   '双小腿疼痛',
#   '左肩疼痛',
#   '活动受限',
#   '左肩疼痛',
#   '受寒',
#   '疼痛',
#   '得热痛减',
#   '疼痛',
#   '活动明显受限',
#   '后伸不能',
#   '发热',
#   '气喘',
#   '气急',
#   '周身乏力',
#   '咳嗽',
#   '失眠',
#   '头晕',
#   '周身乏力',
#   '口腔糜烂',
#   '腰背部疼痛',
#   '晨僵',
#   '双髋疼痛',
#   '晨僵',
#   '弯腰活动受限',
#   '骶髂关节酸痛',
#   '骶髂关节酸痛不适',
#   '右肩疼痛',
#   '咳嗽',
#   '关节痛',
#   '面色略暗',
#   '恶心嗳气',
#   '轻度泛酸',
#   '口粘',
#   '口苦',
#   '咳嗽',
#   '黄脓痰',
#   '四肢关节疼痛',
#   '头晕',
#   '冷汗',
#   '腰臀部疼痛',
#   '活动受限',
#   '右下肢放射性疼痛',
#   '腰臀部疼痛',
#   '不能弯腰',
#   '右下肢放射性痛',
#   '四肢多关节肿痛',
#   '右腕关节肿胀',
#   '小便频急痛',
#   '四肢多关节肿痛',
#   '右腕关节肿胀',
#   '多关节肿痛',
#   '多关节肿痛',
#   '多关节肿痛',
#   '晨僵',
#   '活动欠利',
#   '右肩关节肿痛',
#   '晨僵',
#   '活动欠利',
#   '胃部胀痛',
#   '泛酸',
#   '嗳气',
#   '胃脘胀满疼痛',
#   '冷痛',
#   '隐痛',
#   '嗳气',
#   '反酸',
#   '消瘦',
#   '纳呆',
#   '多关节疼痛',
#   '恶寒喜暖',
#   '中上腹不适',
#   '关节肿痛',
#   '眼干',
#   '关节肿痛',
#   '眼干',
#   '关节痛',
#   '多关节肿痛',
#   '双手关节肿痛',
#   '双手关节肿痛',
#   '疼痛',
#   '肿痛',
#   '四肢多关节肿痛',
#   '双手指间关节肿痛',
#   '肿痛',
#   '颜面少量红斑疹',
#   '轻度瘙痒',
#   '晨僵',
#   '眼干',
#   '口干',
#   '嗳气',
#   '嗳气',
#   '饱胀',
#   '稀便',
#   '饱胀',
#   '稀便',
#   '头晕',
#   '腹胀',
#   '脐周阵发性疼痛不适',
#   '大便稀溏',
#   '四肢多关节肿痛',
#   '关节肿痛',
#   '四肢多关节肿痛',
#   '关节肿痛',
#   '痒',
#   '不适',
#   '疼痛',
#   '活动受限',
#   '乏力',
#   '下肢酸软',
#   '咳嗽',
#   '咳痰',
#   '痰少不易咔',
#   '纳差',
#   '大便欠畅',
#   '夜寐欠安',
#   '左足麻木',
#   '双足跟疼痛',
#   '乏力',
#   '乏力',
#   '嗜睡',
#   '左膝关节肿痛',
#   '腰背痛',
#   '腰背痛',
#   '红斑皮损',
#   '双眼反复干涩',
#   '右膝关节疼痛',
#   '红',
#   '流泪',
#   '左手掌指关节肿痛',
#   '双膝关节疼痛',
#   '活动不利',
#   '疼痛',
#   '活动不利',
#   '四肢关节肿痛2',
#   '四肢关节肿痛',
#   '畸形',
#   '活动受限',
#   '疼痛',
#   '活动不利',
#   '肩部',
#   '外伤',
#   '单关节肿痛',
#   '四肢多关节肿痛',
#   '全身多关节疼痛',
#   '双肩关节疼痛不适',
#   '肿胀',
#   '疼痛',
#   '行走困难',
#   '四肢关节肿痛',
#   '四肢关节肿痛',
#   '关节畸形',
#   '活动受限',
#   '嗳气',
#   '手指足趾关节肿痛',
#   '晨僵',
#   '口干',
#   '便秘',
#   '腰酸',
#   '头晕',
#   '反复头晕',
#   '胸闷',
#   '心悸',
#   '吸烟史',
#   '咯痰',
#   '关节疼痛',
#   '头晕',
#   '头晕',
#   '目眩',
#   '面色淡白',
#   '神倦乏力',
#   '心悸少寐',
#   '右踝部疼痛',
#   '右踝疼痛',
#   '心悸',
#   '胸闷',
#   '板滞',
#   '酸痛',
#   '头晕',
#   '不适',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '咳嗽',
#   '腰膝疼痛',
#   '痛如针刺',
#   '胸闷',
#   '头晕',
#   '头胀',
#   '咽痛',
#   '鼻塞',
#   '咳嗽',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰',
#   '发热',
#   '胃痛',
#   '不适',
#   '发胀',
#   '嗳气',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '痰少',
#   '发热',
#   '干咳',
#   '发热',
#   '吐泻',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰',
#   '干咳',
#   '尿频',
#   '尿痛',
#   '膝关节疼痛不适',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '痰少',
#   '咽痛',
#   '鼻塞',
#   '流涕',
#   '咳嗽',
#   '咳痰色白',
#   '不适',
#   '闷胀',
#   '不适',
#   '打嗝',
#   '不适',
#   '腰痛',
#   '复诊。无',
#   '右侧乳房疼痛',
#   '头痛',
#   '便秘',
#   '口干',
#   '肿',
#   '痒感',
#   '胸闷',
#   '心悸',
#   '睡眠不佳',
#   '痛',
#   '面部发疹',
#   '皮疹',
#   '瘙痒',
#   '睡眠障碍',
#   '猩红热患者接触',
#   '咽痛',
#   '发热感',
#   '右膝下蹲困难',
#   '右下肢肿痛',
#   '发热',
#   '腹胀',
#   '头晕不适',
#   '咳嗽',
#   '咳嗽',
#   '流涕',
#   '头晕',
#   '头晕',
#   '右耳不适',
#   '耳内闷堵',
#   '左眼异物感',
#   '反酸不适',
#   '烧心不适',
#   '左眼肿物',
#   '小腹会阴部酸胀',
#   '尿频',
#   '腰酸',
#   '腹痛',
#   '腹胀不适',
#   '右上后牙咬裂一半',
#   '右上后牙不适',
#   '右小腿术后',
#   '腰椎疼痛',
#   '颈部不适',
#   '左上肢麻木',
#   '反复阵发性头晕',
#   '长期失眠',
#   '咳嗽',
#   '咽痒',
#   '干咳',
#   '少痰',
#   '痰色白',
#   '质粘',
#   '胸痛',
#   '大便干结',
#   '双膝关节疼痛',
#   '夜尿2-4次',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '咽痒',
#   '牙龈疼痛',
#   '咀嚼困难',
#   '左上后牙有洞',
#   '左上后牙有洞',
#   '心悸不适',
#   '阵发性疼痛',
#   '活动不利',
#   '右膝关节痛',
#   '头晕目眩',
#   '健忘少寐',
#   '听力下降',
#   '四肢困倦',
#   '下肢步履无力',
#   '鼻塞',
#   '咽痛',
#   '心悸不适',
#   '活动后胸闷心悸',
#   '气促',
#   '汗出较多',
#   '口干不著',
#   '左下后牙出现肿痛',
#   '头痛',
#   '头晕',
#   '耳鸣',
#   '头晕',
#   '乏力',
#   '腰酸',
#   '口干喜饮',
#   '板滞',
#   '酸痛',
#   '左上肢麻木不适',
#   '劳累后症状加重',
#   '入夜后尤甚',
#   '板滞',
#   '酸痛',
#   '失眠多梦',
#   '肢体麻木',
#   '右下后牙龈肿胀',
#   '伸长',
#   '松动',
#   '咀嚼痛',
#   '轻度畏寒',
#   '发热',
#   '双膝关节疼痛',
#   '活动后加剧',
#   '咳嗽',
#   '咳痰',
#   '咳嗽',
#   '咳黄痰',
#   '痰不畅',
#   '夜间为甚',
#   '声哑',
#   '右侧面部麻木',
#   '右侧面部麻木',
#   '易疲劳',
#   '咳嗽',
#   '咳痰',
#   '咳嗽',
#   '咳黄痰',
#   '咽痛',
#   '左侧面部疼痛',
#   '左侧面部疼痛',
#   '短暂阵发性剧痛',
#   '咳嗽',
#   '间歇性胸痛',
#   '间歇性胸痛',
#   '咳嗽',
#   '咳痰',
#   '鼻塞',
#   '流涕',
#   '咽痛',
#   '周身酸痛',
#   '咽痛',
#   '咳嗽',
#   '咳痰',
#   '咽痛',
#   '周身酸痛',
#   '呕吐',
#   '腹痛',
#   '腹痛',
#   '呕吐',
#   '中上腹胀满',
#   '疼痛不适',
#   '头晕',
#   '头晕',
#   '乏力',
#   '心前区不适',
#   '心前区不适',
#   '哮喘',
#   '咳嗽',
#   '发热',
#   '发热',
#   '发热',
#   '发热',
#   '发热',
#   '咳嗽',
#   '咳嗽',
#   '昼夜咳嗽',
#   '咳黄粘痰',
#   '鼻塞',
#   '眩晕',
#   '头晕',
#   '乏力',
#   '手麻',
#   '发热',
#   '全身酸痛',
#   '全身乏力',
#   '头胀',
#   '发热',
#   '咽痛',
#   '咳嗽',
#   '补液',
#   '咳嗽有痰',
#   '头痛',
#   '流剃',
#   '咳嗽',
#   '头痛',
#   '流剃',
#   '畏寒',
#   '轻度咳嗽',
#   '咬（抓）伤复诊',
#   '发热',
#   '畏寒',
#   '发热',
#   '鼻塞',
#   '咽痛',
#   '咳嗽',
#   '咳嗽',
#   '咳痰',
#   '痰黄',
#   '咳剧时气促',
#   '头晕',
#   '腰酸',
#   '尿色加深',
#   '腰酸',
#   '尿色加深',
#   '发热',
#   '胀',
#   '酸痛',
#   '畏寒',
#   '发热',
#   '咳嗽',
#   '发热',
#   '咳嗽',
#   '咳痰',
#   '痰黄',
#   '咽痛',
#   '发热',
#   '气促',
#   '胸闷',
#   '胸痛',
#   '肢体肿胀',
#   '精神疲乏',
#   '腰酸',
#   '气短',
#   '关节肿痛',
#   '腰痛',
#   '疼痛',
#   '双上臂疼痛',
#   '夜间腰痛尤甚',
#   '四肢关节肿痛',
#   '四肢关节肿痛',
#   '右膝疼痛',
#   '盗汗',
#   '双手关节疼痛',
#   '双手近端指间关节疼痛',
#   '晨僵',
#   '疼痛',
#   '右膝肿痛',
#   '左膝肿痛',
#   '关节肿痛',
#   '双膝疼痛',
#   '双手关节疼痛',
#   '双手关节肿痛',
#   '左腰肋部疼痛',
#   '左肩关节疼痛',
#   '左肩关节疼痛',
#   '夜间痛',
#   '四肢多关节肿痛',
#   '肿痛',
#   '晨僵',
#   '咳嗽',
#   '咳痰',
#   '气急',
#   '痰色黄质粘',
#   '气急',
#   '四肢多关节肿痛',
#   '咳嗽咽痛',
#   '咳痰',
#   '颈项不适',
#   '双肩疼痛',
#   '眼干',
#   '口干',
#   '鼻塞',
#   '流涕',
#   '右侧腰臀部酸痛不适',
#   '腰痛',
#   '活动受限',
#   '四肢多关节肿痛',
#   '四肢多关节反复肿痛',
#   '晨僵',
#   '手关节肿痛',
#   '关节肿痛',
#   '活动受限',
#   '双膝乏力疼痛',
#   '关节肿痛',
#   '腰膝疼痛',
#   '视物模糊',
#   '上腹饱胀',
#   '上腹饱胀',
#   '肿痛不适',
#   '腰痛',
#   '腰痛',
#   '关节痛',
#   '疼痛',
#   '肿痛不适',
#   '肿痛不适',
#   '双手第三指掌指关节疼痛',
#   '双手第三指掌指关节疼痛',
#   '双腕关节不适',
#   '腰腿痛',
#   '腰腿痛',
#   '腰腿痛',
#   '肿痛不适',
#   '肿痛不适',
#   '肿痛不适',
#   '颈椎不适',
#   '颈椎不适',
#   '右肩疼痛',
#   '咽喉不利',
#   '咳嗽',
#   '有痰',
#   '头晕',
#   '头胀',
#   '口干',
#   '口渴',
#   '大便难解',
#   '饱胀稀便',
#   '饱胀稀便',
#   '关节痛',
#   '左膝反复肿痛',
#   '左膝肿痛',
#   '晨僵',
#   '关节疼痛',
#   '颞颌关节疼痛',
#   '四肢关节板滞怕冷',
#   '左肩关节疼痛不适',
#   '口干',
#   '眼干',
#   '右颈肩部不适',
#   '右侧颈肩不适',
#   '关节痛',
#   '四肢多关节肿痛',
#   '肿痛',
#   '晨僵',
#   '右手MCP1肿痛',
#   '左踝关节肿胀疼痛',
#   '左膝关节肿痛',
#   '左膝关节疼痛',
#   '右肩酸痛',
#   '双膝关节疼痛',
#   '咽痒',
#   '咳嗽',
#   '发热',
#   '头晕',
#   '肢体乏力',
#   '双下肢行走发飘',
#   '头晕',
#   '右足肿块',
#   '腹泻',
#   '右肩疼痛',
#   '四肢关节疼痛',
#   '颈部板滞酸痛不适',
#   '腰痛',
#   '夜间翻身疼痛',
#   '双腕关节疼痛',
#   '关节肿痛',
#   '关节肿痛',
#   ...]}

# %%
word2id = dp.buildVocab('word2id.pkl','corpus')
# Out:
# 1234
