# %%
步骤：
* 人工打标签前的工作：去除每行文本中的空格
* 人工打标签前的工作：把大文件转化为20行的小文件
* 要标注的小文件merge成大的csv
* 构建corpus
* 构建word2id

# %%
import datapreprocessing as dp
import os

# %%
corpus_dir = 'D:\\Desktop\\产品\\辅诊\\已标n'

# %%
dp.mergeCSV(corpus_dir)
# Out:
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_31.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_32.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_33.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_34.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_35.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_36.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_37.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_38.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_39.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_40.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_41.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_42.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_43.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_44.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_45.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_46.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_47.csv
# D:\Desktop\产品\辅诊\已标n\markedru1_tb_cis_mzdzbl_48.csv
# ...

# %%
dp.buildCorpus(os.path.join(corpus_dir,'merged.csv'),os.path.join(corpus_dir,'corpus'))
# Out:
# {'1b': ['皮肤病史',
#   '排除/AS',
#   '慢性病史',
#   '药物过敏史',
#   '慢性病史',
#   '药物过敏史',
#   '心脏病史',
#   '慢性病史',
#   '药物过敏史',
#   '药敏',
#   '糖尿病',
#   '高血压',
#   '心脏病史',
#   '慢性病史',
#   '药物过敏史',
#   '慢性疾病',
#   '药物过敏史',
#   '慢性病史',
#   '干燥综合征',
#   '慢性病史',
#   '慢性病史',
#   '冠心病',
#   '高血压',
#   '糖尿病',
#   '慢性病史',
#   '慢性病史',
#   '心脏病史',
#   '糖尿病史',
#   '食物、药物过敏史',
#   '食物、药物过敏史',
#   '食物、药物过敏史',
#   '药物过敏史',
#   '药敏史',
#   '虹睫炎',
#   '虹睫炎',
#   '风湿性关节炎',
#   '类风湿性关节炎',
#   '强直性脊柱炎',
#   '骨性关节炎',
#   '虹睫炎',
#   '糖尿病',
#   '高血压',
#   '糖尿病病史'],
#  '1jc': ['狭窄',
#   '栓塞',
#   '狭窄',
#   '尿蛋白',
#   '错位性骨折征象',
#   '阳性检查结果',
#   '狭窄',
#   '异常',
#   '浸润',
#   '残留直肠息肉',
#   '新发灶',
#   '浸润',
#   '残留直肠息肉',
#   '新发灶',
#   '狭窄',
#   '狭窄',
#   '狭窄',
#   '缺血型ST-T改变',
#   '淋巴门',
#   '缺血性STT改变',
#   '停搏',
#   '狭窄',
#   '异常',
#   'PR(-)',
#   '异常',
#   '异常',
#   '眼科检查眼底血管(-)',
#   '异常',
#   '扩张',
#   '狭窄',
#   '异常',
#   '尿蛋白'],
#  '1s': ['外伤史',
#   '外伤',
#   '外伤',
#   '外伤',
#   '外伤史',
#   '外伤史',
#   '外伤',
# ...

# %%
word2id = dp.buildVocab('word2id.pkl','corpus')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-14b16fcde593> in <module>()
# ----> 1 word2id = dp.buildVocab('word2id.pkl','corpus')
#
# D:\github\E-Tagging\code\datapreprocessing.py in buildVocab(vocab_path, corpus_path, min_count)
#     242         :return:
#     243 	"""
# --> 244         data = readCorpus(corpus_path)
#     245         word2id = {}
#     246         for sent_, tag_ in data:
#
# D:\github\E-Tagging\code\datapreprocessing.py in readCorpus(corpus_path)
#     216 	"""
#     217         data = []
# --> 218         with open(corpus_path, encoding='utf-8') as fr:
#     219                 lines = fr.readlines()
#     220         sent_, tag_ = [], []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'corpus'
